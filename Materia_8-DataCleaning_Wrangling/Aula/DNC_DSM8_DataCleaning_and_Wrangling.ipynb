# %% [markdown]
# # Data Cleaning & Wrangling

# %% [markdown]
# ## Manipulação de Dados

# %%
import pandas as pd

# %%
path = "C:/Users/bianc/OneDrive/Documents/1-Estudos/2-DNC/1-Data Science/1-Material/Materis8-DataCleaning_Wrangling/MichineLearning/DataCW-main/DataCW-main/Datasets"

# %%
path + "/good.json"
# Out:
# 'C:/Users/bianc/OneDrive/Documents/1-Estudos/2-DNC/1-Data Science/1-Material/Materis8-DataCleaning_Wrangling/MichineLearning/DataCW-main/DataCW-main/Datasets/good.json'

# %%
df = pd.read_json(path + "/good.json")
df
# Out:
#                                        audio_features
# 0   {'danceability': 0.749, 'energy': 0.839, 'key'...
# 1   {'danceability': 0.5730000000000001, 'energy':...
# 2   {'danceability': 0.8, 'energy': 0.719, 'key': ...
# 3   {'danceability': 0.778, 'energy': 0.632, 'key'...
# 4   {'danceability': 0.797, 'energy': 0.852, 'key'...
# ..                                                ...
# 95  {'danceability': 0.616, 'energy': 0.534, 'key'...
# 96  {'danceability': 0.802, 'energy': 0.549, 'key'...
# 97  {'danceability': 0.767, 'energy': 0.659, 'key'...
# 98  {'danceability': 0.752, 'energy': 0.468, 'key'...
# 99  {'danceability': 0.797, 'energy': 0.654, 'key'...
#
# [100 rows x 1 columns]

# %%
df_musics = pd.json_normalize(df["audio_features"])
df_musics
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.749   0.839    6    -4.847     1       0.2970        0.0867
# 1          0.573   0.581   10    -9.026     0       0.3390        0.7530
# 2          0.800   0.719    7    -6.262     1       0.2340        0.1090
# 3          0.778   0.632    8    -6.415     1       0.1250        0.0404
# 4          0.797   0.852    8    -5.202     1       0.2410        0.0555
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.616   0.534   10   -10.264     0       0.4830        0.6390
# 96         0.802   0.549    5    -8.600     0       0.0631        0.2680
# 97         0.767   0.659    7    -4.541     1       0.0387        0.7850
# 98         0.752   0.468    0    -9.966     1       0.3330        0.8050
# 99         0.797   0.654    8    -7.373     1       0.2450        0.6330
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
df_musics.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
df_musics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      100 non-null    float64
#  1   energy            100 non-null    float64
#  2   key               100 non-null    int64
#  3   loudness          100 non-null    float64
#  4   mode              100 non-null    int64
#  5   speechiness       100 non-null    float64
#  6   acousticness      100 non-null    float64
#  7   instrumentalness  100 non-null    float64
#  8   liveness          100 non-null    float64
#  9   valence           100 non-null    float64
#  10  tempo             100 non-null    float64
#  11  type              100 non-null    object
#  12  id                100 non-null    object
#  13  uri               100 non-null    object
#  14  track_href        100 non-null    object
#  15  analysis_url      100 non-null    object
# ...

# %%
path + "/athletes.csv"
# Out:
# 'C:/Users/bianc/OneDrive/Documents/1-Estudos/2-DNC/1-Data Science/1-Material/Materis8-DataCleaning_Wrangling/MichineLearning/DataCW-main/DataCW-main/Datasets/athletes.csv'

# %%
df_athletes = pd.read_csv(path + "/athletes.csv")
df_athletes
# Out:
#           code                        name     name_short  \
# 0      1532872            ALEKSANYAN Artur   ALEKSANYAN A
# 1      1532873              AMOYAN Malkhas       AMOYAN M
# 2      1532874             GALSTYAN Slavik     GALSTYAN S
# 3      1532944           HARUTYUNYAN Arsen  HARUTYUNYAN A
# 4      1532945             TEVANYAN Vazgen     TEVANYAN V
# ...        ...                         ...            ...
# 11105  4982175               JOSEPH Elijah       JOSEPH E
# 11106  4982762             HOMAN Khrystyna        HOMAN K
# 11107  4983537  CHELANGAT Annet Chemengich   CHELANGAT AC
# 11108  4986655              ADA ETO Sefora      ADA ETO S
# 11109  9460001             LIUZZI Emanuela       LIUZZI E
#
#                           name_tv  gender function country_code  \
# 0                Artur ALEKSANYAN    Male  Athlete          ARM
# 1                  Malkhas AMOYAN    Male  Athlete          ARM
# 2                 Slavik GALSTYAN    Male  Athlete          ARM
# ...

# %%
df_athletes.dtypes
# Out:
# code                    int64
# name                   object
# name_short             object
# name_tv                object
# gender                 object
# function               object
# country_code           object
# country                object
# country_full           object
# nationality            object
# nationality_full       object
# nationality_code       object
# height                  int64
# weight                float64
# disciplines            object
# events                 object
# birth_date             object
# birth_place            object
# birth_country          object
# residence_place        object
# residence_country      object
# nickname               object
# hobbies                object
# occupation             object
# education              object
# family                 object
# lang                   object
# coach                  object
# reason                 object
# hero                   object
# influence              object
# ...

# %%
df_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11110 entries, 0 to 11109
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   code                11110 non-null  int64
#  1   name                11110 non-null  object
#  2   name_short          11110 non-null  object
#  3   name_tv             11110 non-null  object
#  4   gender              11110 non-null  object
#  5   function            11110 non-null  object
#  6   country_code        11110 non-null  object
#  7   country             11110 non-null  object
#  8   country_full        11110 non-null  object
#  9   nationality         11091 non-null  object
#  10  nationality_full    11091 non-null  object
#  11  nationality_code    11091 non-null  object
#  12  height              11110 non-null  int64
#  13  weight              11092 non-null  float64
#  14  disciplines         11110 non-null  object
# ...

# %%
df_athletes["code"].astype(str)
# Out:
# 0        1532872
# 1        1532873
# 2        1532874
# 3        1532944
# 4        1532945
#           ...
# 11105    4982175
# 11106    4982762
# 11107    4983537
# 11108    4986655
# 11109    9460001
# Name: code, Length: 11110, dtype: object

# %%
pd.to_datetime(df_athletes["birth_date"])
# Out:
# 0       1991-10-21
# 1       1999-01-22
# 2       1996-12-21
# 3       1999-11-22
# 4       1999-10-27
#            ...
# 11105   2001-07-03
# 11106   1999-01-31
# 11107   1993-07-29
# 11108   2003-06-11
# 11109   2000-04-27
# Name: birth_date, Length: 11110, dtype: datetime64[ns]

# %% [markdown]
# ### Filtando dados:

# %%
df_athletes[df_athletes["country_full"] == "Brazil"]
# Out:
#           code                       name      name_short  \
# 1413   1561237            CARDOSO Adriana       CARDOSO A
# 1414   1561239         BOLZAN Ana Claudia       BOLZAN AC
# 1415   1561242           ARENHART Barbara      ARENHART B
# 1416   1561243             de PAULA Bruna      de PAULA B
# 1417   1561248            BITOLO Gabriela        BITOLO G
# ...        ...                        ...             ...
# 9985   1968115             PESSOA Rodrigo        PESSOA R
# 9986   1968116                FONSECA Ruy       FONSECA R
# 9987   1968118  de FREITAS BARCHA Stephan  BARCHA Stephan
# 9988   1968125                MANSUR Yuri        MANSUR Y
# 10951  3430817          SCHEFFER Fernando      SCHEFFER F
#
#                          name_tv  gender           function country_code  \
# 1413             Adriana CARDOSO  Female            Athlete          BRA
# 1414          Ana Claudia BOLZAN  Female            Athlete          BRA
# ...

# %%
df_brazil = df_athletes[df_athletes["country_full"] == "Brazil"]

# %%
df_brazil.shape
# Out:
# (290, 35)

# %%
df_brazil[df_brazil["nationality"] != "Brazil"]
# Out:
#          code          name name_short       name_tv gender  \
# 9980  1968081  PARRO Carlos    PARRO C  Carlos PARRO   Male
#
#                function country_code country country_full nationality  ...  \
# 9980  Alternate Athlete          BRA  Brazil       Brazil       Italy  ...
#
#                                          family                 lang  \
# 9980  Wife, Nicola. Son, Luca. Daughter, Margot  English, Portuguese
#
#                                                   coach  \
# 9980  National (jumping): Mark Todd (NZL).<br>Person...
#
#                                                  reason  \
# 9980  He developed an interest in horses while stayi...
#
#                                                    hero influence philosophy  \
# 9980  Equestrian eventing rider Mark Todd (NZL), six...       NaN        NaN
#
#                                      sporting_relatives ritual other_sports
# 9980  Older brother, Andre Parro (equestrian), repre...    NaN          NaN
#
# ...

# %%
df_athletes[df_athletes["country_full"] != "Brazil"]
# Out:
#           code                        name     name_short  \
# 0      1532872            ALEKSANYAN Artur   ALEKSANYAN A
# 1      1532873              AMOYAN Malkhas       AMOYAN M
# 2      1532874             GALSTYAN Slavik     GALSTYAN S
# 3      1532944           HARUTYUNYAN Arsen  HARUTYUNYAN A
# 4      1532945             TEVANYAN Vazgen     TEVANYAN V
# ...        ...                         ...            ...
# 11105  4982175               JOSEPH Elijah       JOSEPH E
# 11106  4982762             HOMAN Khrystyna        HOMAN K
# 11107  4983537  CHELANGAT Annet Chemengich   CHELANGAT AC
# 11108  4986655              ADA ETO Sefora      ADA ETO S
# 11109  9460001             LIUZZI Emanuela       LIUZZI E
#
#                           name_tv  gender function country_code  \
# 0                Artur ALEKSANYAN    Male  Athlete          ARM
# 1                  Malkhas AMOYAN    Male  Athlete          ARM
# 2                 Slavik GALSTYAN    Male  Athlete          ARM
# ...

# %%
df_athletes[df_athletes["country_full"].isin(["Brazil", "Argentina"]) ]
# Out:
#           code                       name      name_short  \
# 101    1535729             SERRANO Franco       SERRANO F
# 199    1537180          CEBALLOS Macarena      CEBALLOS M
# 208    1537209              HEIN Agostina          HEIN A
# 230    1537465             SARAVIA Ulises       SARAVIA U
# 231    1537510          BORELLI Florencia       BORELLI F
# ...        ...                        ...             ...
# 9986   1968116                FONSECA Ruy       FONSECA R
# 9987   1968118  de FREITAS BARCHA Stephan  BARCHA Stephan
# 9988   1968125                MANSUR Yuri        MANSUR Y
# 10951  3430817          SCHEFFER Fernando      SCHEFFER F
# 10987  3556435           SIMEONE Giuliano       SIMEONE G
#
#                          name_tv  gender function country_code    country  \
# 101               Franco SERRANO    Male  Athlete          ARG  Argentina
# 199            Macarena CEBALLOS  Female  Athlete          ARG  Argentina
# ...

# %%
df_athletes[df_athletes["height"] >= 200]
# Out:
#           code                  name      name_short               name_tv  \
# 399    1540143     FISCHER Guillermo       FISCHER G     Guillermo FISCHER
# 701    1544444          RAFTERY Jack       RAFTERY J          Jack RAFTERY
# 1091   1552386       FABBRI Leonardo        FABBRI L       Leonardo FABBRI
# 1244   1556225  COLODROVSCHI Silvian  COLODROVSCHI S  Silvian COLODROVSCHI
# 1248   1556230      IUDEAN Francesco        IUDEAN F      Francesco IUDEAN
# ...        ...                   ...             ...                   ...
# 10880  1981495             MOZIC Rok         MOZIC R                 MOZIC
# 10882  1981504         STALEKAR Saso      STALEKAR S              STALEKAR
# 10889  1981540           URNAUT Tine        URNAUT T                URNAUT
# 10892  1981548          STERN Toncek         STERN T              T. STERN
# 10895  1981556          KASTELIC Urh      KASTELIC U          Urh KASTELIC
#
# ...

# %%
df_athletes[df_athletes["height"] >= 200].shape
# Out:
# (254, 35)

# %%
### df[(df[col] == condicao) & df([col] != codicao)]

# %%
df_athletes[(df_athletes["height"] >= 200) & (df_athletes["gender"] == "Female")]
# Out:
#          code                         name   name_short          name_tv  \
# 4065  1901580  MARTINEZ Brayelin Elizabeth  MARTINEZ BE         MARTINEZ
# 4099  1901743                       HAN Xu        HAN X           HAN Xu
# 4102  1901747                     LI Yueru         LI Y         LI Yueru
# 4666  1907854  GONZALEZ Geraldine Sthefany  GONZALEZ GS         GONZALEZ
# 5197  1913664                  YUAN Xinyue       YUAN X         YUAN X.Y
# 5444  1917759                  RETTKE Dana     RETTKE D           RETTKE
# 5843  1921743          ANTROPOVA Ekaterina  ANTROPOVA E        ANTROPOVA
# 6488  1928422           KORNELUK Agnieszka   KORNELUK A         KORNELUK
# 6494  1928441            STYSIAK Magdalena    STYSIAK M          STYSIAK
# 8821  1954735              GRINER Brittney     GRINER B  Brittney GRINER
#
#       gender function country_code             country  \
# 4065  Female  Athlete          DOM  Dominican Republic
# ...

# %%
df_athletes[(df_athletes["height"] >= 170) | (df_athletes["country_full"] == "Brazil")]
# Out:
#           code                        name     name_short  \
# 8      1533176             CAMARA Ebrahima       CAMARA E
# 12     1533208            MAAROUFOU Hachim    MAAROUFOU H
# 25     1533364              ISMAIL Mohamed       ISMAIL M
# 26     1533371              HASSAN Ibrahim       HASSAN I
# 27     1533372                  WAISS Abdi        WAISS A
# ...        ...                         ...            ...
# 11099  4979564               WILSON Quincy       WILSON Q
# 11100  4979565                  KING Brynn         KING B
# 11102  4979624        PAPAMICHAIL Despoina  PAPAMICHAIL D
# 11105  4982175               JOSEPH Elijah       JOSEPH E
# 11107  4983537  CHELANGAT Annet Chemengich   CHELANGAT AC
#
#                           name_tv  gender function country_code  \
# 8                 Ebrahima CAMARA    Male  Athlete          GAM
# 12               Hachim MAAROUFOU    Male  Athlete          COM
# 25                 Mohamed ISMAIL    Male  Athlete          DJI
# ...

# %%
df_athletes[~(df_athletes["height"] >= 170) | (df_athletes["country_full"] == "Brazil")][["country_full", "height"]]
# Out:
#                            country_full  height
# 0                               Armenia       0
# 1                               Armenia       0
# 2                               Armenia       0
# 3                               Armenia       0
# 4                               Armenia       0
# ...                                 ...     ...
# 11103  Lao People's Democratic Republic       0
# 11104                       Netherlands     168
# 11106                           Ukraine       0
# 11108                 Equatorial Guinea     165
# 11109                             Italy       0
#
# [7226 rows x 2 columns]

# %% [markdown]
# ### Calculando frequência

# %%
df_brazil.shape
# Out:
# (290, 35)

# %%
df_brazil["gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df_brazil["gender"].unique
# Out:
# <bound method Series.unique of 1413     Female
# 1414     Female
# 1415     Female
# 1416     Female
# 1417     Female
#           ...
# 9985       Male
# 9986       Male
# 9987       Male
# 9988       Male
# 10951      Male
# Name: gender, Length: 290, dtype: object>

# %%
df_athletes["gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_athletes["country_code"].nunique()
# Out:
# 206

# %%
df_brazil.loc[df_brazil["height"] != 0, "height"].mode()
# Out:
# 0    175
# Name: height, dtype: int64

# %%
df_brazil["gender"].mode()
# Out:
# 0    Female
# Name: gender, dtype: object

# %%
df_brazil["gender"].value_counts()
# Out:
# gender
# Female    164
# Male      126
# Name: count, dtype: int64

# %%
df_brazil["gender"].value_counts(normalize=True) * 100
# Out:
# gender
# Female    56.551724
# Male      43.448276
# Name: proportion, dtype: float64

# %%
df_athletes["country_full"].value_counts(normalize=True) * 100
# Out:
# country_full
# United States of America    5.571557
# France                      5.400540
# Australia                   4.275428
# Germany                     4.113411
# Japan                       3.879388
#                               ...
# Tuvalu                      0.018002
# Liechtenstein               0.009001
# Belize                      0.009001
# Somalia                     0.009001
# Nauru                       0.009001
# Name: proportion, Length: 206, dtype: float64

# %%
df_athletes["country_full"].value_counts()
# Out:
# country_full
# United States of America    619
# France                      600
# Australia                   475
# Germany                     457
# Japan                       431
#                            ...
# Tuvalu                        2
# Liechtenstein                 1
# Belize                        1
# Somalia                       1
# Nauru                         1
# Name: count, Length: 206, dtype: int64

# %%
df_athletes["country_full"].value_counts(ascending=True)
# Out:
# country_full
# Liechtenstein                 1
# Belize                        1
# Nauru                         1
# Somalia                       1
# Andorra                       2
#                            ...
# Japan                       431
# Germany                     457
# Australia                   475
# France                      600
# United States of America    619
# Name: count, Length: 206, dtype: int64

# %%
df_athletes["country_full"].value_counts(sort=False)
# Out:
# country_full
# Armenia                                   15
# Colombia                                  88
# Jamaica                                   65
# Gambia                                     7
# Mexico                                   108
#                                         ...
# Nauru                                      1
# Philippines                               22
# Switzerland                              137
# Democratic People's Republic of Korea     14
# Slovenia                                  95
# Name: count, Length: 206, dtype: int64

# %%
df_athletes["height"].value_counts()
# Out:
# height
# 0      6032
# 170     291
# 180     246
# 175     237
# 178     206
#        ...
# 222       1
# 151       1
# 140       1
# 217       1
# 214       1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# ### Agrupamentos

# %%
df_athletes.groupby("country_full").size().sort_values(ascending=False)
# Out:
# country_full
# United States of America    619
# France                      600
# Australia                   475
# Germany                     457
# Japan                       431
#                            ...
# Myanmar                       2
# Belize                        1
# Liechtenstein                 1
# Nauru                         1
# Somalia                       1
# Length: 206, dtype: int64

# %%
df_positive_values = df_athletes[df_athletes["height"] > 0]

# %%
df_positive_values
# Out:
#           code                        name       name_short  \
# 5      1532951               ARENAS Lorena         ARENAS L
# 7      1533136    BASS BITTAYE Gina Mariam  BASS BITTAYE GM
# 8      1533176             CAMARA Ebrahima         CAMARA E
# 12     1533208            MAAROUFOU Hachim      MAAROUFOU H
# 25     1533364              ISMAIL Mohamed         ISMAIL M
# ...        ...                         ...              ...
# 11102  4979624        PAPAMICHAIL Despoina    PAPAMICHAIL D
# 11104  4980004            van de WIEL Anne    van de WIEL A
# 11105  4982175               JOSEPH Elijah         JOSEPH E
# 11107  4983537  CHELANGAT Annet Chemengich     CHELANGAT AC
# 11108  4986655              ADA ETO Sefora        ADA ETO S
#
#                           name_tv  gender function country_code  \
# 5                   Lorena ARENAS  Female  Athlete          COL
# 7        Gina Mariam BASS BITTAYE  Female  Athlete          GAM
# ...

# %%
df_positive_values.groupby("country_full")["height"].mean().sort_values()
# Out:
# country_full
# American Samoa            152.000000
# Dominica                  152.000000
# Solomon Islands           152.000000
# Palau                     152.000000
# Myanmar                   158.000000
#                              ...
# Iceland                   190.000000
# Croatia                   191.170732
# Serbia                    191.435897
# Bosnia and Herzegovina    198.000000
# South Sudan               199.071429
# Name: height, Length: 199, dtype: float64

# %%
df_positive_values.groupby("gender")["height"].mean().sort_values()
# Out:
# gender
# Female    172.224828
# Male      185.363916
# Name: height, dtype: float64

# %%
df_positive_values.groupby("gender")[["height","weight"]].mean().sort_values(by="weight")
# Out:
#             height    weight
# gender
# Female  172.224828  4.285598
# Male    185.363916  5.386923

# %%
df_positive_values.groupby("gender")["height"].max()
# Out:
# gender
# Female    205
# Male      222
# Name: height, dtype: int64

# %%
df_positive_values.groupby("gender")["height"].min()
# Out:
# gender
# Female    140
# Male      154
# Name: height, dtype: int64

# %%
df_positive_values.groupby(["country_full", "gender"])["height"].mean()
# Out:
# country_full  gender
# AIN           Female    174.250000
#               Male      191.333333
# Afghanistan   Female    163.000000
#               Male      179.000000
# Albania       Female    161.000000
#                            ...
# Yemen         Male      183.000000
# Zambia        Female    160.238095
#               Male      171.714286
# Zimbabwe      Female    155.000000
#               Male      191.000000
# Name: height, Length: 338, dtype: float64

# %%
df_positive_values.groupby(["country_full", "gender"])["height"].mean().unstack()
# Out:
# gender                       Female        Male
# country_full
# AIN                      174.250000  191.333333
# Afghanistan              163.000000  179.000000
# Albania                  161.000000  193.000000
# Algeria                  171.400000  186.600000
# American Samoa           152.000000         NaN
# ...                             ...         ...
# Virgin Islands, British  157.000000  180.000000
# Virgin Islands, US              NaN  180.000000
# Yemen                           NaN  183.000000
# Zambia                   160.238095  171.714286
# Zimbabwe                 155.000000  191.000000
#
# [199 rows x 2 columns]

# %%
path + "/medals.csv"
# Out:
# 'C:/Users/bianc/OneDrive/Documents/1-Estudos/2-DNC/1-Data Science/1-Material/Materis8-DataCleaning_Wrangling/MichineLearning/DataCW-main/DataCW-main/Datasets/medals.csv'

# %%
df_medals = pd.read_csv(path + "/medals.csv", encoding="latin1")

# %%
df_medals.head()
# Out:
#      medal_type  medal_code  medal_date             name gender    discipline  \
# 0    Gold Medal         1.0  2024-07-27  Remco EVENEPOEL      M  Cycling Road
# 1  Silver Medal         2.0  2024-07-27    Filippo GANNA      M  Cycling Road
# 2  Bronze Medal         3.0  2024-07-27    Wout van AERT      M  Cycling Road
# 3    Gold Medal         1.0  2024-07-27      Grace BROWN      W  Cycling Road
# 4  Silver Medal         2.0  2024-07-27   Anna HENDERSON      W  Cycling Road
#
#                            event event_type  \
# 0    Men's Individual Time Trial        ATH
# 1    Men's Individual Time Trial        ATH
# 2    Men's Individual Time Trial        ATH
# 3  Women's Individual Time Trial        ATH
# 4  Women's Individual Time Trial        ATH
#
#                                            url_event     code country_code  \
# 0  /en/paris-2024/results/cycling-road/men-s-indi...  1903136          BEL
# 1  /en/paris-2024/results/cycling-road/men-s-indi...  1923520          ITA
# ...

# %%
df_medals.groupby("country")["medal_type"].value_counts().unstack
# Out:
# <bound method Series.unstack of country        medal_type
# AIN            Silver Medal     3
#                Bronze Medal     1
#                Gold Medal       1
# Albania        Bronze Medal     2
# Algeria        Gold Medal       2
#                                ..
# United States  Gold Medal      40
# Uzbekistan     Gold Medal       8
#                Bronze Medal     3
#                Silver Medal     2
# Zambia         Bronze Medal     1
# Name: count, Length: 209, dtype: int64>

# %%
df_medals.groupby("country")["medal_type"].value_counts().unstack().sort_values(by=["Gold Medal", "Silver Medal", "Bronze Medal"], ascending=[False, False, False])
# Out:
# medal_type     Bronze Medal  Gold Medal  Silver Medal
# country
# United States          42.0        40.0          44.0
# China                  24.0        40.0          27.0
# Japan                  13.0        20.0          12.0
# Australia              16.0        18.0          19.0
# France                 22.0        16.0          26.0
# ...                     ...         ...           ...
# Peru                    1.0         NaN           NaN
# Qatar                   1.0         NaN           NaN
# Singapore               1.0         NaN           NaN
# Slovakia                1.0         NaN           NaN
# Zambia                  1.0         NaN           NaN
#
# [92 rows x 3 columns]

# %%
df_ordem_medals = df_medals.groupby("country")["medal_type"].value_counts().unstack().sort_values(by=["Gold Medal", "Silver Medal", "Bronze Medal"], ascending=[False, False, False])

# %%
# Reordenar colunas
df_ordem_medals = df_ordem_medals[["Gold Medal", "Silver Medal", "Bronze Medal"]]

# %%
df_ordem_medals
# Out:
# medal_type     Gold Medal  Silver Medal  Bronze Medal
# country
# United States        40.0          44.0          42.0
# China                40.0          27.0          24.0
# Japan                20.0          12.0          13.0
# Australia            18.0          19.0          16.0
# France               16.0          26.0          22.0
# ...                   ...           ...           ...
# Peru                  NaN           NaN           1.0
# Qatar                 NaN           NaN           1.0
# Singapore             NaN           NaN           1.0
# Slovakia              NaN           NaN           1.0
# Zambia                NaN           NaN           1.0
#
# [92 rows x 3 columns]

# %%
# Se quiser manter o índice como coluna
df_ordem_medals.reset_index(inplace=True)

# %%
df_ordem_medals
# Out:
# medal_type        country  Gold Medal  Silver Medal  Bronze Medal
# 0           United States        40.0          44.0          42.0
# 1                   China        40.0          27.0          24.0
# 2                   Japan        20.0          12.0          13.0
# 3               Australia        18.0          19.0          16.0
# 4                  France        16.0          26.0          22.0
# ..                    ...         ...           ...           ...
# 87                   Peru         NaN           NaN           1.0
# 88                  Qatar         NaN           NaN           1.0
# 89              Singapore         NaN           NaN           1.0
# 90               Slovakia         NaN           NaN           1.0
# 91                 Zambia         NaN           NaN           1.0
#
# [92 rows x 4 columns]

# %% [markdown]
# ### Criando Colunas

# %%
df = pd.DataFrame([[1, 10, "A"], [2, 20, "B"],  [3, 30, "C"]], columns=["col1", "col2", "col3"])
df
# Out:
#    col1  col2 col3
# 0     1    10    A
# 1     2    20    B
# 2     3    30    C

# %%
df["my new column"] = 10
df
# Out:
#    col1  col2 col3  my new column
# 0     1    10    A             10
# 1     2    20    B             10
# 2     3    30    C             10

# %%
df["my new column"] = "Teste"
df
# Out:
#    col1  col2 col3 my new column
# 0     1    10    A         Teste
# 1     2    20    B         Teste
# 2     3    30    C         Teste

# %%
df["my new column"] = None
df
# Out:
#    col1  col2 col3 my new column
# 0     1    10    A          None
# 1     2    20    B          None
# 2     3    30    C          None

# %%
df["column"] = [100, 200, 300]
df
# Out:
#    col1  col2 col3 my new column  column
# 0     1    10    A          None     100
# 1     2    20    B          None     200
# 2     3    30    C          None     300

# %%
df["column"] = df["col1"]
df
# Out:
#    col1  col2 col3 my new column  column
# 0     1    10    A          None       1
# 1     2    20    B          None       2
# 2     3    30    C          None       3

# %%
df.assign(test_assing = "value")
# Out:
#    col1  col2 col3 my new column  column test_assing
# 0     1    10    A          None       1       value
# 1     2    20    B          None       2       value
# 2     3    30    C          None       3       value

# %%
df.assign(test_assing = df["col1"])
# Out:
#    col1  col2 col3 my new column  column  test_assing
# 0     1    10    A          None       1            1
# 1     2    20    B          None       2            2
# 2     3    30    C          None       3            3

# %%
df = df.assign(test_assing = df["col1"])
df
# Out:
#    col1  col2 col3 my new column  column  test_assing
# 0     1    10    A          None       1            1
# 1     2    20    B          None       2            2
# 2     3    30    C          None       3            3

# %% [markdown]
# ### Remoção de dados

# %%
df = df.drop(["test_assign", "my new column"], axis="columns", errors="ignore")

# %%
df
# Out:
#    col1  col2 col3  column  test_assing
# 0     1    10    A       1            1
# 1     2    20    B       2            2
# 2     3    30    C       3            3

# %%
df.drop(["column"], axis=1, inplace=True) # axis=1 eh igual a axis="columns"

# %%
df
# Out:
#    col1  col2 col3  test_assing
# 0     1    10    A            1
# 1     2    20    B            2
# 2     3    30    C            3

# %%
df.drop(2, axis=0) # axis=0 eh igual a axis="index"
# Out:
#    col1  col2 col3  test_assing
# 0     1    10    A            1
# 1     2    20    B            2

# %% [markdown]
# ### Operações Aritiméticas

# %%
df_athletes_posive_values = df_athletes[(df_athletes["height"] > 0) & (df_athletes["weight"] > 0)]

# %%
df_athletes_posive_values
# Out:
#           code                name   name_short             name_tv gender  \
# 370    1539950       McNULTY Harry    McNULTY H       Harry McNULTY   Male
# 371    1539951        MOLLEN Bryan     MOLLEN B        Bryan MOLLEN   Male
# 372    1539952       KENNEDY Terry    KENNEDY T       Terry KENNEDY   Male
# 431    1540533       MONETA Marcos     MONETA M       Marcos MONETA   Male
# 432    1540534  VERA FELD Santiago  VERA FELD S  Santiago VERA FELD   Male
# ...        ...                 ...          ...                 ...    ...
# 10954  3500057     MOTUGA Alamanda     MOTUGA A     Alamanda MOTUGA   Male
# 10968  3538849        SMITH Andrew      SMITH A        Andrew SMITH   Male
# 10969  3538850          KELLY Jack      KELLY J          Jack KELLY   Male
# 10970  3538856         KEENAN Hugo     KEENAN H         Hugo KEENAN   Male
# 10986  3555841         LEUTA Matai      LEUTA M         Matai LEUTA   Male
#
# ...

# %%
df_athletes_posive_values.shape
# Out:
# (316, 35)

# %%
df_athletes_posive_values["height"] / 100
# Out:
# 370      1.85
# 371      1.89
# 372      1.83
# 431      1.85
# 432      1.81
#          ...
# 10954    1.84
# 10968    1.83
# 10969    1.85
# 10970    1.85
# 10986    1.89
# Name: height, Length: 316, dtype: float64

# %%
df_athletes_posive_values[["height", "weight"]]
# Out:
#        height  weight
# 370       185    98.0
# 371       189    93.0
# 372       183    84.0
# 431       185    75.0
# 432       181    82.0
# ...       ...     ...
# 10954     184   102.0
# 10968     183    90.0
# 10969     185    86.0
# 10970     185    88.0
# 10986     189   106.0
#
# [316 rows x 2 columns]

# %%
df_athletes_posive_values["height_m"] = df_athletes_posive_values["height"] / 100
# Out:
# C:\Users\bianc\AppData\Local\Temp\ipykernel_94536\3012996146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_athletes_posive_values["height_m"] = df_athletes_posive_values["height"] / 100

# %%
df_athletes_posive_values["height_m"]
# Out:
# 370      1.85
# 371      1.89
# 372      1.83
# 431      1.85
# 432      1.81
#          ...
# 10954    1.84
# 10968    1.83
# 10969    1.85
# 10970    1.85
# 10986    1.89
# Name: height_m, Length: 316, dtype: float64

# %%
# IMC = Peso / Altura^2

# %%
df_athletes_posive_values["imc"] = df_athletes_posive_values["weight"] / (df_athletes_posive_values["height_m"] * df_athletes_posive_values["height_m"])
# Out:
# C:\Users\bianc\AppData\Local\Temp\ipykernel_94536\4262122143.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_athletes_posive_values["imc"] = df_athletes_posive_values["weight"] / (df_athletes_posive_values["height_m"] * df_athletes_posive_values["height_m"])

# %%
df_athletes_posive_values
# Out:
#           code                name   name_short             name_tv gender  \
# 370    1539950       McNULTY Harry    McNULTY H       Harry McNULTY   Male
# 371    1539951        MOLLEN Bryan     MOLLEN B        Bryan MOLLEN   Male
# 372    1539952       KENNEDY Terry    KENNEDY T       Terry KENNEDY   Male
# 431    1540533       MONETA Marcos     MONETA M       Marcos MONETA   Male
# 432    1540534  VERA FELD Santiago  VERA FELD S  Santiago VERA FELD   Male
# ...        ...                 ...          ...                 ...    ...
# 10954  3500057     MOTUGA Alamanda     MOTUGA A     Alamanda MOTUGA   Male
# 10968  3538849        SMITH Andrew      SMITH A        Andrew SMITH   Male
# 10969  3538850          KELLY Jack      KELLY J          Jack KELLY   Male
# 10970  3538856         KEENAN Hugo     KEENAN H         Hugo KEENAN   Male
# 10986  3555841         LEUTA Matai      LEUTA M         Matai LEUTA   Male
#
# ...

# %%
df_athletes["birth_date"] = pd.to_datetime(df_athletes["birth_date"])

# %%
from datetime import datetime, timedelta

# %%
start_date = datetime(2024, 7, 26)

# %%
df_athletes["age"] = start_date - df_athletes["birth_date"]

# %%
df_athletes["age"] = df_athletes["age"] / timedelta(days=365)

# %%
df_athletes["age"]
# Out:
# 0        32.786301
# 1        25.526027
# 2        27.613699
# 3        24.693151
# 4        24.764384
#            ...
# 11105    23.079452
# 11106    25.501370
# 11107    31.013699
# 11108    21.139726
# 11109    24.263014
# Name: age, Length: 11110, dtype: float64

# %%
df_athletes["name"] + " - " + df_athletes["country_code"]
# Out:
# 0                  ALEKSANYAN Artur - ARM
# 1                    AMOYAN Malkhas - ARM
# 2                   GALSTYAN Slavik - ARM
# 3                 HARUTYUNYAN Arsen - ARM
# 4                   TEVANYAN Vazgen - ARM
#                        ...
# 11105                 JOSEPH Elijah - TTO
# 11106               HOMAN Khrystyna - UKR
# 11107    CHELANGAT Annet Chemengich - UGA
# 11108                ADA ETO Sefora - GEQ
# 11109               LIUZZI Emanuela - ITA
# Length: 11110, dtype: object

# %% [markdown]
# ### Funções

# %%
def is_adult(age):
    if age >= 18:
        return "Sim"
    else:
        return "Não"

# %%
is_adult(20)
# Out:
# 'Sim'

# %%
df_athletes["is_adult"] = df_athletes["age"].apply(is_adult)

# %%
df_athletes["is_adult"].value_counts()
# Out:
# is_adult
# Sim    10907
# Não      203
# Name: count, dtype: int64

# %%
df_athletes["is_adult"].value_counts(normalize=True) * 100
# Out:
# is_adult
# Sim    98.172817
# Não     1.827183
# Name: proportion, dtype: float64

# %%
def computer_col_functions(col):
    max_value = col.max()
    min_value = col.min()
    mean_value = col.mean()
    median_value = col.median()

    return pd.Series({
        "max": max_value,
        "min": min_value,
        "mean": mean_value,
        "median": median_value
    })

# %%
df_athletes[["height", "weight", "age"]].apply(computer_col_functions)
# Out:
#            height     weight        age
# max     222.00000  113.00000  69.698630
# min       0.00000    0.00000  11.964384
# mean     81.79883    2.21511  27.066354
# median    0.00000    0.00000  26.497260

# %%
def create_description_column(row):
    name = row["name"]
    country = row["country_full"]

    return f"{name} | {country}"

# %%
df_athletes.apply(create_description_column, axis=1)
# Out:
# 0                 ALEKSANYAN Artur | Armenia
# 1                   AMOYAN Malkhas | Armenia
# 2                  GALSTYAN Slavik | Armenia
# 3                HARUTYUNYAN Arsen | Armenia
# 4                  TEVANYAN Vazgen | Armenia
#                         ...
# 11105    JOSEPH Elijah | Trinidad and Tobago
# 11106              HOMAN Khrystyna | Ukraine
# 11107    CHELANGAT Annet Chemengich | Uganda
# 11108     ADA ETO Sefora | Equatorial Guinea
# 11109                LIUZZI Emanuela | Italy
# Length: 11110, dtype: object

# %%
df_athletes["height"].apply(lambda x: x / 100)
# Out:
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
#          ...
# 11105    1.77
# 11106    0.00
# 11107    1.74
# 11108    1.65
# 11109    0.00
# Name: height, Length: 11110, dtype: float64

# %%
df_athletes["age"].apply(lambda age: "Sim" if age >= 18 else "Não")
# Out:
# 0        Sim
# 1        Sim
# 2        Sim
# 3        Sim
# 4        Sim
#         ...
# 11105    Sim
# 11106    Sim
# 11107    Sim
# 11108    Sim
# 11109    Sim
# Name: age, Length: 11110, dtype: object

# %%
df_athletes[["height", "weight", "age"]].apply(lambda col: col[col > 0].mean())
# Out:
# height    178.965144
# weight     77.753165
# age        27.066354
# dtype: float64

# %%
df_athletes.apply(lambda row: f"Atleta: {row['name']} | {row['country']}", axis=1)
# Out:
# 0                 Atleta: ALEKSANYAN Artur | Armenia
# 1                   Atleta: AMOYAN Malkhas | Armenia
# 2                  Atleta: GALSTYAN Slavik | Armenia
# 3                Atleta: HARUTYUNYAN Arsen | Armenia
# 4                  Atleta: TEVANYAN Vazgen | Armenia
#                             ...
# 11105    Atleta: JOSEPH Elijah | Trinidad and Tobago
# 11106              Atleta: HOMAN Khrystyna | Ukraine
# 11107    Atleta: CHELANGAT Annet Chemengich | Uganda
# 11108     Atleta: ADA ETO Sefora | Equatorial Guinea
# 11109                Atleta: LIUZZI Emanuela | Italy
# Length: 11110, dtype: object

# %%
df_athletes.iloc[0]
# Out:
# code                                                            1532872
# name                                                   ALEKSANYAN Artur
# name_short                                                 ALEKSANYAN A
# name_tv                                                Artur ALEKSANYAN
# gender                                                             Male
# function                                                        Athlete
# country_code                                                        ARM
# country                                                         Armenia
# country_full                                                    Armenia
# nationality                                                     Armenia
# nationality_full                                                Armenia
# nationality_code                                                    ARM
# height                                                                0
# ...

# %%
type(df_athletes.iloc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Discretização

# %% [markdown]
# #### Uniforme

# %%
df_athletes["age"]
# Out:
# 0        32.786301
# 1        25.526027
# 2        27.613699
# 3        24.693151
# 4        24.764384
#            ...
# 11105    23.079452
# 11106    25.501370
# 11107    31.013699
# 11108    21.139726
# 11109    24.263014
# Name: age, Length: 11110, dtype: float64

# %%
df_athletes["age"].max()
# Out:
# np.float64(69.6986301369863)

# %%
df_uniform = pd.cut(df_athletes["age"], bins=4)
df_uniform.value_counts()
# Out:
# age
# (11.907, 26.398]    5463
# (26.398, 40.832]    5455
# (40.832, 55.265]     171
# (55.265, 69.699]      21
# Name: count, dtype: int64

# %%
df_uniform.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# #### Baseado na frequencia

# %%
df_quantiles = pd.qcut(df_athletes["age"], q=4)
df_quantiles.value_counts()
# Out:
# age
# (11.963000000000001, 23.362]    2780
# (26.497, 30.038]                2780
# (23.362, 26.497]                2775
# (30.038, 69.699]                2775
# Name: count, dtype: int64

# %%
df_quantiles.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# #### Personalizado

# %%
ranges_age = [0, 18, 30, 50, 70]
df_customized = pd.cut(df_athletes["age"], bins=ranges_age)

# %%
df_customized.value_counts()
# Out:
# age
# (18, 30]    8106
# (30, 50]    2762
# (0, 18]      203
# (50, 70]      39
# Name: count, dtype: int64

# %%
df_customized.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ### Junção de Tabelas

# %% [markdown]
# #### Merge

# %%
df_athletes.head()
# Out:
#       code               name     name_short            name_tv gender  \
# 0  1532872   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN   Male
# 1  1532873     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN   Male
# 2  1532874    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN   Male
# 3  1532944  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN   Male
# 4  1532945    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN   Male
#
#   function country_code  country country_full nationality  ...  \
# 0  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 1  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 2  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 3  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 4  Athlete          ARM  Armenia      Armenia     Armenia  ...
#
#                                                coach  \
# 0                    Gevorg Aleksanyan (ARM), father
# ...

# %%
df_athletes.columns
# Out:
# Index(['code', 'name', 'name_short', 'name_tv', 'gender', 'function',
#        'country_code', 'country', 'country_full', 'nationality',
#        'nationality_full', 'nationality_code', 'height', 'weight',
#        'disciplines', 'events', 'birth_date', 'birth_place', 'birth_country',
#        'residence_place', 'residence_country', 'nickname', 'hobbies',
#        'occupation', 'education', 'family', 'lang', 'coach', 'reason', 'hero',
#        'influence', 'philosophy', 'sporting_relatives', 'ritual',
#        'other_sports', 'age', 'is_adult'],
#       dtype='object')

# %%
df_medals.head()
# Out:
#      medal_type  medal_code  medal_date             name gender    discipline  \
# 0    Gold Medal         1.0  2024-07-27  Remco EVENEPOEL      M  Cycling Road
# 1  Silver Medal         2.0  2024-07-27    Filippo GANNA      M  Cycling Road
# 2  Bronze Medal         3.0  2024-07-27    Wout van AERT      M  Cycling Road
# 3    Gold Medal         1.0  2024-07-27      Grace BROWN      W  Cycling Road
# 4  Silver Medal         2.0  2024-07-27   Anna HENDERSON      W  Cycling Road
#
#                            event event_type  \
# 0    Men's Individual Time Trial        ATH
# 1    Men's Individual Time Trial        ATH
# 2    Men's Individual Time Trial        ATH
# 3  Women's Individual Time Trial        ATH
# 4  Women's Individual Time Trial        ATH
#
#                                            url_event     code country_code  \
# 0  /en/paris-2024/results/cycling-road/men-s-indi...  1903136          BEL
# 1  /en/paris-2024/results/cycling-road/men-s-indi...  1923520          ITA
# ...

# %%
df_medals.columns
# Out:
# Index(['medal_type', 'medal_code', 'medal_date', 'name', 'gender',
#        'discipline', 'event', 'event_type', 'url_event', 'code',
#        'country_code', 'country', 'country_long'],
#       dtype='object')

# %%
df_athletes["code"].dtype
# Out:
# dtype('int64')

# %%
df_medals["code"].dtype
# Out:
# dtype('O')

# %%
df_athletes["code"] = df_athletes["code"].astype(str)

# %%
df_results_left = df_athletes.merge(right=df_medals[["code", "medal_type", "medal_date", "discipline", "event"]], on="code", how="left")

# %%
df_results_left.head()
# Out:
#       code               name     name_short            name_tv gender  \
# 0  1532872   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN   Male
# 1  1532873     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN   Male
# 2  1532874    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN   Male
# 3  1532944  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN   Male
# 4  1532945    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN   Male
#
#   function country_code  country country_full nationality  ...  \
# 0  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 1  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 2  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 3  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 4  Athlete          ARM  Armenia      Armenia     Armenia  ...
#
#                                           philosophy  \
# 0  "Wrestling is my life." (mediamax.am. 18 May 2...
# ...

# %%
df_results_left.shape
# Out:
# (11162, 41)

# %%
df_results_inner = df_athletes.merge(right=df_medals[["code", "medal_type", "medal_date", "discipline", "event"]], on="code", how="inner")

# %%
df_results_inner.head()
# Out:
#       code                        name         name_short  \
# 0  1532872            ALEKSANYAN Artur       ALEKSANYAN A
# 1  1532873              AMOYAN Malkhas           AMOYAN M
# 2  1535187  VERDE ALVAREZ Marco Alonso   VERDE ALVAREZ MA
# 3  1535349         OLVERA IBARRA Osmar    OLVERA IBARRA O
# 4  1535513   RENTERIA RENTERIA Tatiana  RENTERIA RENTERIA
#
#                       name_tv  gender function country_code   country  \
# 0            Artur ALEKSANYAN    Male  Athlete          ARM   Armenia
# 1              Malkhas AMOYAN    Male  Athlete          ARM   Armenia
# 2  Marco Alonso VERDE ALVAREZ    Male  Athlete          MEX    Mexico
# 3         Osmar OLVERA IBARRA    Male  Athlete          MEX    Mexico
# 4   Tatiana RENTERIA RENTERIA  Female  Athlete          COL  Colombia
#
#   country_full nationality  ...  \
# 0      Armenia     Armenia  ...
# 1      Armenia     Armenia  ...
# 2       Mexico      Mexico  ...
# 3       Mexico      Mexico  ...
# ...

# %%
df_results_inner.shape
# Out:
# (760, 41)

# %% [markdown]
# #### Concat

# %% [markdown]
# ##### Linhas

# %%
data1 = {'col1': [1, 2, 3],
        'col2': [4, 5, 6],
        'col3': [7, 8, 9]}
df1 = pd.DataFrame(data1)

data2 = {'col1': [10, 11, 12],
        'col2': [13, 14, 15],
        'col3': [16, 17, 18]}
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df2
# Out:
#    col1  col2  col3
# 0    10    13    16
# 1    11    14    17
# 2    12    15    18

# %%
pd.concat([df1, df2], axis=0, ignore_index=True)  # axis=0 para concatenar linhas
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
# 3    10    13    16
# 4    11    14    17
# 5    12    15    18

# %% [markdown]
# ##### Colunas

# %%
data3 = {'col4': [10, 11, 12, 100],
        'col5': [13, 14, 15, 100],
        'col6': [16, 17, 18, 100]}
df3 = pd.DataFrame(data3)

# %%
pd.concat([df1, df3], axis=1, ignore_index=True)  # axis=1 para concatenar colunas
# Out:
#      0    1    2    3    4    5
# 0  1.0  4.0  7.0   10   13   16
# 1  2.0  5.0  8.0   11   14   17
# 2  3.0  6.0  9.0   12   15   18
# 3  NaN  NaN  NaN  100  100  100

# %% [markdown]
# #### Append

# %%
df_athletes_aux = df_athletes[["name", "age", "gender", "country_full", "disciplines"]]

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
"""" Descontinuado em função do append estar depreciado
 df_athletes_aux.append({
    "name": "GAMA Milton",
    "age": 28,
    "gender": "Male",
    "country_full": "Brazil",
    "disciplines": "['Data Science']"
}, ignore_index=True)
"""

# Nova linha como DataFrame
nova_linha = pd.DataFrame([{
    "name": "GAMA Milton",
    "age": 28,
    "gender": "Male",
    "country_full": "Brazil",
    "disciplines": "['Data Science']"
}])

# %%
df_athletes_aux = pd.concat([df_athletes_aux, nova_linha], ignore_index=True)

# %%
df_athletes_aux
# Out:
#                              name        age  gender       country_full  \
# 0                ALEKSANYAN Artur  32.786301    Male            Armenia
# 1                  AMOYAN Malkhas  25.526027    Male            Armenia
# 2                 GALSTYAN Slavik  27.613699    Male            Armenia
# 3               HARUTYUNYAN Arsen  24.693151    Male            Armenia
# 4                 TEVANYAN Vazgen  24.764384    Male            Armenia
# ...                           ...        ...     ...                ...
# 11106             HOMAN Khrystyna  25.501370  Female            Ukraine
# 11107  CHELANGAT Annet Chemengich  31.013699  Female             Uganda
# 11108              ADA ETO Sefora  21.139726  Female  Equatorial Guinea
# 11109             LIUZZI Emanuela  24.263014  Female              Italy
# 11110                 GAMA Milton  28.000000    Male             Brazil
#
#             disciplines
# 0         ['Wrestling']
# 1         ['Wrestling']
# 2         ['Wrestling']
# ...

# %% [markdown]
# ## Limpeza de Dados

# %% [markdown]
# ### Granularidade dos dados

# %%
df_athletes.head()
# Out:
#       code               name     name_short            name_tv gender  \
# 0  1532872   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN   Male
# 1  1532873     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN   Male
# 2  1532874    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN   Male
# 3  1532944  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN   Male
# 4  1532945    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN   Male
#
#   function country_code  country country_full nationality  ...  \
# 0  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 1  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 2  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 3  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 4  Athlete          ARM  Armenia      Armenia     Armenia  ...
#
#                                                coach  \
# 0                    Gevorg Aleksanyan (ARM), father
# ...

# %%
df_athletes["code"].value_counts()
# Out:
# code
# 1532872    1
# 1532873    1
# 1532874    1
# 1532944    1
# 1532945    1
#           ..
# 4982175    1
# 4982762    1
# 4983537    1
# 4986655    1
# 9460001    1
# Name: count, Length: 11110, dtype: int64

# %%
df_athletes["code"].nunique()
# Out:
# 11110

# %%
df_athletes.shape
# Out:
# (11110, 37)

# %%
df_athletes["name"].nunique()
# Out:
# 11100

# %%
df_medals.head()
# Out:
#      medal_type  medal_code  medal_date             name gender    discipline  \
# 0    Gold Medal         1.0  2024-07-27  Remco EVENEPOEL      M  Cycling Road
# 1  Silver Medal         2.0  2024-07-27    Filippo GANNA      M  Cycling Road
# 2  Bronze Medal         3.0  2024-07-27    Wout van AERT      M  Cycling Road
# 3    Gold Medal         1.0  2024-07-27      Grace BROWN      W  Cycling Road
# 4  Silver Medal         2.0  2024-07-27   Anna HENDERSON      W  Cycling Road
#
#                            event event_type  \
# 0    Men's Individual Time Trial        ATH
# 1    Men's Individual Time Trial        ATH
# 2    Men's Individual Time Trial        ATH
# 3  Women's Individual Time Trial        ATH
# 4  Women's Individual Time Trial        ATH
#
#                                            url_event     code country_code  \
# 0  /en/paris-2024/results/cycling-road/men-s-indi...  1903136          BEL
# 1  /en/paris-2024/results/cycling-road/men-s-indi...  1923520          ITA
# ...

# %%
df_medals["code"].value_counts()
# Out:
# code
# 1909294    4
# 1967140    4
# 1935938    3
# 1959861    3
# 1946150    3
#           ..
# 1548948    1
# 1923694    1
# 1903112    1
# 1977926    1
# 1895596    1
# Name: count, Length: 992, dtype: int64

# %%
df_medals.shape
# Out:
# (1044, 13)

# %%
df_medals.groupby(["code", "event"]).size()
# Out:
# code               event
# 1532872            Men's Greco-Roman 97kg    1
# 1532873            Men's Greco-Roman 77kg    1
# 1535187            Men's 71kg                1
# 1535349            Men's 3m Springboard      1
# 1535513            Women's Freestyle 76kg    1
#                                             ..
# WPOMTEAM7---SRB01  Men                       1
# WPOMTEAM7---USA01  Men                       1
# WPOWTEAM7---AUS01  Women                     1
# WPOWTEAM7---ESP01  Women                     1
# WPOWTEAM7---NED01  Women                     1
# Length: 1044, dtype: int64

# %%
df_medals.groupby(["code", "event"]).size().max()
# Out:
# np.int64(1)

# %%
df_athletes.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11105    False
# 11106    False
# 11107    False
# 11108    False
# 11109    False
# Length: 11110, dtype: bool

# %%
df_athletes.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_athletes[df_athletes.duplicated()]
# Out:
# Empty DataFrame
# Columns: [code, name, name_short, name_tv, gender, function, country_code, country, country_full, nationality, nationality_full, nationality_code, height, weight, disciplines, events, birth_date, birth_place, birth_country, residence_place, residence_country, nickname, hobbies, occupation, education, family, lang, coach, reason, hero, influence, philosophy, sporting_relatives, ritual, other_sports, age, is_adult]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_medals.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1039    False
# 1040    False
# 1041    False
# 1042    False
# 1043    False
# Length: 1044, dtype: bool

# %%
df_medals.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_medals.duplicated(subset=["code", "event"]).sum()
# Out:
# np.int64(0)

# %%
df_medals.duplicated(subset=["code", "medal_type"]).sum()
# Out:
# np.int64(31)

# %%
df_medals.drop_duplicates(subset=["code"], keep="first")
# Out:
#         medal_type  medal_code  medal_date                       name gender  \
# 0       Gold Medal         1.0  2024-07-27            Remco EVENEPOEL      M
# 1     Silver Medal         2.0  2024-07-27              Filippo GANNA      M
# 2     Bronze Medal         3.0  2024-07-27              Wout van AERT      M
# 3       Gold Medal         1.0  2024-07-27                Grace BROWN      W
# 4     Silver Medal         2.0  2024-07-27             Anna HENDERSON      W
# ...            ...         ...         ...                        ...    ...
# 1039  Silver Medal         2.0  2024-08-09             KALEYN Boryana      W
# 1040  Bronze Medal         3.0  2024-08-09             RAFFAELI Sofia      W
# 1041    Gold Medal         1.0  2024-08-09           THIAM Nafissatou      W
# 1042  Silver Medal         2.0  2024-08-09  JOHNSON-THOMPSON Katarina      W
# 1043  Bronze Medal         3.0  2024-08-09                 VIDTS Noor      W
#
# ...

# %% [markdown]
# ### Operações com Strings

# %%
path + "/amazon.csv"
# Out:
# 'C:/Users/bianc/OneDrive/Documents/1-Estudos/2-DNC/1-Data Science/1-Material/Materis8-DataCleaning_Wrangling/MichineLearning/DataCW-main/DataCW-main/Datasets/amazon.csv'

# %%
df_amazon = pd.read_csv(path + "/amazon.csv", encoding="latin1", on_bad_lines="skip")

# %%
df_amazon.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ¹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ¹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ¹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ¹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ¹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ¹1,099                 64%    4.2       24,269
# ...

# %%
df_amazon.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
df_amazon["category"].str.lower()
# Out:
# 0       computers&accessories|accessories&peripherals|...
# 1       computers&accessories|accessories&peripherals|...
# 2       computers&accessories|accessories&peripherals|...
# 3       computers&accessories|accessories&peripherals|...
# 4       computers&accessories|accessories&peripherals|...
#                               ...
# 1428    home&kitchen|kitchen&homeappliances|waterpurif...
# 1429    home&kitchen|kitchen&homeappliances|smallkitch...
# 1430    home&kitchen|heating,cooling&airquality|roomhe...
# 1431    home&kitchen|heating,cooling&airquality|fans|e...
# 1432    home&kitchen|kitchen&homeappliances|smallkitch...
# Name: category, Length: 1433, dtype: object

# %%
df_amazon["category"].value_counts()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          232
# Electronics|WearableTechnology|SmartWatches                                                                                 72
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        64
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               61
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                                                 49
#                                                                                                                           ...
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|RotiMakers                                                        1
# ...

# %%
df_amazon[df_amazon["category"].str.lower().str.startswith("electronics")]
# Out:
#      product_id                                       product_name  \
# 12   B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 16   B0B6F7LX4C  MI 80 cm (32 inches) 5A Series HD Ready Smart ...
# 19   B08DPLCM6T  LG 80 cm (32 inches) HD Ready Smart LED TV 32L...
# 21   B085194JFL  tizum HDMI to VGA Adapter Cable 1080P for Proj...
# 22   B09F6S8BT6  Samsung 80 cm (32 Inches) Wondertainment Serie...
# ..          ...                                                ...
# 987  B014SZPBM4           Duracell Ultra Alkaline D Battery, 2 Pcs
# 990  B078W65FJ7  boAt BassHeads 900 On-Ear Wired Headphones wit...
# 991  B08S74GTBT  Zebronics Astra 10 Portable Wireless BT v5.0 S...
# 992  B0B9BD2YL4  KINGONE Wireless Charging Pencil (2nd Generati...
# 996  B07W7Z6DVL  Infinity (JBL Fuze 100, Wireless Portable Blue...
#
#                                               category discounted_price  \
# 12   Electronics|HomeTheater,TV&Video|Accessories|C...             ¹219
# ...

# %%
df_amazon[df_amazon["category"].str.lower().str.startswith("electronics")]["category"].value_counts()
# Out:
# category
# Electronics|WearableTechnology|SmartWatches                                                                       72
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                              64
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                     61
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                                       49
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                      48
#                                                                                                                   ..
# Electronics|Cameras&Photography|Accessories|Batteries&Chargers|BatteryChargers                                     1
# Electronics|HomeAudio|Speakers|SoundbarSpeakers                                                                    1
# ...

# %%
df_amazon_electronics = df_amazon[df_amazon["category"].str.lower().str.startswith("electronics")]

# %%
df_amazon_electronics["category"].value_counts()
# Out:
# category
# Electronics|WearableTechnology|SmartWatches                                                                       72
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                              64
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                     61
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                                       49
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                      48
#                                                                                                                   ..
# Electronics|Cameras&Photography|Accessories|Batteries&Chargers|BatteryChargers                                     1
# Electronics|HomeAudio|Speakers|SoundbarSpeakers                                                                    1
# ...

# %%
df_amazon[df_amazon["category"].str.lower().str.contains("smartwatches")]
# Out:
#      product_id                                       product_name  \
# 331  B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 332  B0B3RRWSF6  Fire-Boltt Phoenix Smart Watch with Bluetooth ...
# 333  B0B5B6PQCT  boAt Wave Call Smart Watch, Smart Talk with Ad...
# 340  B0B5LVS732  Noise Pulse Go Buzz Smart Watch Bluetooth Call...
# 342  B09V12K8NT  boAt Wave Lite Smartwatch with 1.69" HD Displa...
# ..          ...                                                ...
# 806  B09RKFBCV7  Fire-Boltt Ninja Calling 1.69" Bluetooth Calli...
# 840  B09NC2TY11  Noise ColorFit Ultra Buzz Bluetooth Calling Sm...
# 843  B09YV575RK  Fire-Boltt Ring Pro Bluetooth Calling, 1.75
#  3...
# 886  B094JB13XL  Noise ColorFit Ultra Smart Watch with 1.75" HD...
# 920  B09TBCVJS3  Amazfit GTS2 Mini (New Version) Smart Watch wi...
#
#                                         category discounted_price  \
# 331  Electronics|WearableTechnology|SmartWatches           ¹1,799
# ...

# %%
"Teste"[0]
# Out:
# 'T'

# %%
df_amazon["moeda"] = df_amazon["actual_price"].str[0]

# %%
df_amazon["moeda"].str[0]
# Out:
# 0       ¹
# 1       ¹
# 2       ¹
# 3       ¹
# 4       ¹
#        ..
# 1428    ¹
# 1429    ¹
# 1430    ¹
# 1431    ¹
# 1432    ¹
# Name: moeda, Length: 1433, dtype: object

# %%
df_amazon["moeda"].value_counts()
# Out:
# moeda
# ¹    1433
# Name: count, dtype: int64

# %%
df_amazon["actual_price"].str[-3:]
# Out:
# 0       099
# 1       349
# 2       899
# 3       699
# 4       399
#        ...
# 1428    919
# 1429    045
# 1430    080
# 1431    890
# 1432    690
# Name: actual_price, Length: 1433, dtype: object

# %%
df_amazon["product_name"].str.strip()
# Out:
# 0       Wayona Nylon Braided USB to Lightning Fast Cha...
# 1       Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2       Sounce Fast Phone Charging Cable & Data Sync U...
# 3       boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4       Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#                               ...
# 1428    Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1429    Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1430    Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1431    Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1432    Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# Name: product_name, Length: 1433, dtype: object

# %%
df_amazon["category"].str.split("|")
# Out:
# 0       [Computers&Accessories, Accessories&Peripheral...
# 1       [Computers&Accessories, Accessories&Peripheral...
# 2       [Computers&Accessories, Accessories&Peripheral...
# 3       [Computers&Accessories, Accessories&Peripheral...
# 4       [Computers&Accessories, Accessories&Peripheral...
#                               ...
# 1428    [Home&Kitchen, Kitchen&HomeAppliances, WaterPu...
# 1429    [Home&Kitchen, Kitchen&HomeAppliances, SmallKi...
# 1430    [Home&Kitchen, Heating,Cooling&AirQuality, Roo...
# 1431    [Home&Kitchen, Heating,Cooling&AirQuality, Fan...
# 1432    [Home&Kitchen, Kitchen&HomeAppliances, SmallKi...
# Name: category, Length: 1433, dtype: object

# %%
df_category_macro = df_amazon["category"].str.split("|", expand=True)[0].rename("Categoria_Macro")

# %%
df_category_macro
# Out:
# 0       Computers&Accessories
# 1       Computers&Accessories
# 2       Computers&Accessories
# 3       Computers&Accessories
# 4       Computers&Accessories
#                 ...
# 1428             Home&Kitchen
# 1429             Home&Kitchen
# 1430             Home&Kitchen
# 1431             Home&Kitchen
# 1432             Home&Kitchen
# Name: Categoria_Macro, Length: 1433, dtype: object

# %%
df_amazon = pd.concat([df_amazon, df_category_macro], axis=1)

# %%
df_amazon["Categoria_Macro"].value_counts()
# Out:
# Categoria_Macro
# Electronics              505
# Computers&Accessories    449
# Home&Kitchen             441
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %% [markdown]
# ### Operações com Datas

# %%
df_athletes["birth_date"]
# Out:
# 0       1991-10-21
# 1       1999-01-22
# 2       1996-12-21
# 3       1999-11-22
# 4       1999-10-27
#            ...
# 11105   2001-07-03
# 11106   1999-01-31
# 11107   1993-07-29
# 11108   2003-06-11
# 11109   2000-04-27
# Name: birth_date, Length: 11110, dtype: datetime64[ns]

# %%
df_athletes["birth_date"] = pd.to_datetime(df_athletes["birth_date"])

# %%
pd.to_datetime(df_athletes["birth_date"], format="%Y-%m-%d") # d/m/Y
# Out:
# 0       1991-10-21
# 1       1999-01-22
# 2       1996-12-21
# 3       1999-11-22
# 4       1999-10-27
#            ...
# 11105   2001-07-03
# 11106   1999-01-31
# 11107   1993-07-29
# 11108   2003-06-11
# 11109   2000-04-27
# Name: birth_date, Length: 11110, dtype: datetime64[ns]

# %%
df_athletes["birth_date"].dt.year
# Out:
# 0        1991
# 1        1999
# 2        1996
# 3        1999
# 4        1999
#          ...
# 11105    2001
# 11106    1999
# 11107    1993
# 11108    2003
# 11109    2000
# Name: birth_date, Length: 11110, dtype: int32

# %%
df_athletes["birth_date"].dt.day
# Out:
# 0        21
# 1        22
# 2        21
# 3        22
# 4        27
#          ..
# 11105     3
# 11106    31
# 11107    29
# 11108    11
# 11109    27
# Name: birth_date, Length: 11110, dtype: int32

# %%
df_athletes["birth_date"].dt.month.head()
# Out:
# 0    10
# 1     1
# 2    12
# 3    11
# 4    10
# Name: birth_date, dtype: int32

# %%
df_athletes["birth_date"].dt.day_name()
# Out:
# 0           Monday
# 1           Friday
# 2         Saturday
# 3           Monday
# 4        Wednesday
#            ...
# 11105      Tuesday
# 11106       Sunday
# 11107     Thursday
# 11108    Wednesday
# 11109     Thursday
# Name: birth_date, Length: 11110, dtype: object

# %%
df_athletes["birth_date"].dt.day_of_week
# Out:
# 0        0
# 1        4
# 2        5
# 3        0
# 4        2
#         ..
# 11105    1
# 11106    6
# 11107    3
# 11108    2
# 11109    3
# Name: birth_date, Length: 11110, dtype: int32

# %%
from datetime import datetime

# %%
today_datetime = datetime.now()

# %%
today_datetime
# Out:
# datetime.datetime(2025, 12, 1, 17, 18, 47, 393319)

# %%
df_athletes["age_today"] = today_datetime.year - df_athletes["birth_date"].dt.year

# %%
df_athletes
# Out:
#           code                        name     name_short  \
# 0      1532872            ALEKSANYAN Artur   ALEKSANYAN A
# 1      1532873              AMOYAN Malkhas       AMOYAN M
# 2      1532874             GALSTYAN Slavik     GALSTYAN S
# 3      1532944           HARUTYUNYAN Arsen  HARUTYUNYAN A
# 4      1532945             TEVANYAN Vazgen     TEVANYAN V
# ...        ...                         ...            ...
# 11105  4982175               JOSEPH Elijah       JOSEPH E
# 11106  4982762             HOMAN Khrystyna        HOMAN K
# 11107  4983537  CHELANGAT Annet Chemengich   CHELANGAT AC
# 11108  4986655              ADA ETO Sefora      ADA ETO S
# 11109  9460001             LIUZZI Emanuela       LIUZZI E
#
#                           name_tv  gender function country_code  \
# 0                Artur ALEKSANYAN    Male  Athlete          ARM
# 1                  Malkhas AMOYAN    Male  Athlete          ARM
# 2                 Slavik GALSTYAN    Male  Athlete          ARM
# ...

# %%
df_athletes["age_today"]
# Out:
# 0        34
# 1        26
# 2        29
# 3        26
# 4        26
#          ..
# 11105    24
# 11106    26
# 11107    32
# 11108    22
# 11109    25
# Name: age_today, Length: 11110, dtype: int32

# %%
df_athletes[df_athletes["birth_date"] >= "2000-01-01"].shape
# Out:
# (3885, 38)

# %%
df_athletes.groupby(df_athletes["birth_date"].dt.year).size().plot()
# Out:
# <Axes: xlabel='birth_date'>

# %%
df_athletes.groupby(df_athletes["birth_date"].dt.month).size().plot(kind="bar")
# Out:
# <Axes: xlabel='birth_date'>

# %%
df_athletes.groupby(df_athletes["birth_date"].dt.to_period("M")).size().plot()
# Out:
# <Axes: xlabel='birth_date'>

# %% [markdown]
# ### Dados Faltantes

# %%
df_athletes.head()
# Out:
#       code               name     name_short            name_tv gender  \
# 0  1532872   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN   Male
# 1  1532873     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN   Male
# 2  1532874    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN   Male
# 3  1532944  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN   Male
# 4  1532945    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN   Male
#
#   function country_code  country country_full nationality  ...  \
# 0  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 1  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 2  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 3  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 4  Athlete          ARM  Armenia      Armenia     Armenia  ...
#
#                                               reason  \
# 0  He followed his father and his uncle into the ...
# ...

# %%
df_athletes.isnull()
# Out:
#         code   name  name_short  name_tv  gender  function  country_code  \
# 0      False  False       False    False   False     False         False
# 1      False  False       False    False   False     False         False
# 2      False  False       False    False   False     False         False
# 3      False  False       False    False   False     False         False
# 4      False  False       False    False   False     False         False
# ...      ...    ...         ...      ...     ...       ...           ...
# 11105  False  False       False    False   False     False         False
# 11106  False  False       False    False   False     False         False
# 11107  False  False       False    False   False     False         False
# 11108  False  False       False    False   False     False         False
# 11109  False  False       False    False   False     False         False
#
#        country  country_full  nationality  ...  reason   hero  influence  \
# ...

# %%
print(df_athletes.isnull().sum())
# Out:
# code                      0
# name                      0
# name_short                0
# name_tv                   0
# gender                    0
# function                  0
# country_code              0
# country                   0
# country_full              0
# nationality              19
# nationality_full         19
# nationality_code         19
# height                    0
# weight                   18
# disciplines               0
# events                    0
# birth_date                0
# birth_place            2397
# birth_country          1649
# residence_place        4318
# residence_country      2834
# nickname               8147
# hobbies                6909
# occupation             1539
# education              5579
# family                 5555
# lang                    522
# coach                  2898
# reason                 5272
# hero                   7798
# influence              8959
# philosophy             8331
# sporting_relatives     8594
# ...

# %%
((df_athletes.isnull().sum() / df_athletes.shape[0]) * 100).sort_values(ascending=False)
# Out:
# ritual                92.295230
# other_sports          90.486049
# influence             80.639064
# sporting_relatives    77.353735
# philosophy            74.986499
# nickname              73.330333
# hero                  70.189019
# hobbies               62.187219
# education             50.216022
# family                50.000000
# reason                47.452745
# residence_place       38.865887
# coach                 26.084608
# residence_country     25.508551
# birth_place           21.575158
# birth_country         14.842484
# occupation            13.852385
# lang                   4.698470
# nationality_full       0.171017
# nationality_code       0.171017
# nationality            0.171017
# weight                 0.162016
# function               0.000000
# gender                 0.000000
# name_tv                0.000000
# name_short             0.000000
# name                   0.000000
# code                   0.000000
# country_code           0.000000
# ...

# %%
df_athletes.isnull().sum(axis=1)
# Out:
# 0         3
# 1        11
# 2        14
# 3         6
# 4         9
#          ..
# 11105    15
# 11106     4
# 11107    14
# 11108    12
# 11109    19
# Length: 11110, dtype: int64

# %%
(df_athletes.isnull().sum(axis=1) / df_athletes.shape[1] * 100).sort_values(ascending=False)
# Out:
# 5072     57.894737
# 4880     57.894737
# 5901     57.894737
# 2686     57.894737
# 9838     57.894737
#            ...
# 4999      0.000000
# 8503      0.000000
# 2025      0.000000
# 2977      0.000000
# 10425     0.000000
# Length: 11110, dtype: float64

# %%
df_athletes[~df_athletes["hero"].isnull()]
# Out:
#           code                      name       name_short  \
# 0      1532872          ALEKSANYAN Artur     ALEKSANYAN A
# 3      1532944         HARUTYUNYAN Arsen    HARUTYUNYAN A
# 5      1532951             ARENAS Lorena         ARENAS L
# 6      1533112           McKENZIE Ashley       McKENZIE A
# 7      1533136  BASS BITTAYE Gina Mariam  BASS BITTAYE GM
# ...        ...                       ...              ...
# 11045  4678919           CHOULOUTE Mayah      CHOULOUTE M
# 11054  4846949            NIJJAR Jasneet         NIJJAR J
# 11056  4849459       PERMATAHANI Azzahra    PERMATAHANI A
# 11060  4966765       ADAMOPOULOU Ariadni    ADAMOPOULOU A
# 11073  4969017            HAN Phone Pyae           HAN PP
#
#                         name_tv  gender function country_code    country  \
# 0              Artur ALEKSANYAN    Male  Athlete          ARM    Armenia
# 3             Arsen HARUTYUNYAN    Male  Athlete          ARM    Armenia
# ...

# %%
df_athletes[df_athletes["hero"].notnull()]
# Out:
#           code                      name       name_short  \
# 0      1532872          ALEKSANYAN Artur     ALEKSANYAN A
# 3      1532944         HARUTYUNYAN Arsen    HARUTYUNYAN A
# 5      1532951             ARENAS Lorena         ARENAS L
# 6      1533112           McKENZIE Ashley       McKENZIE A
# 7      1533136  BASS BITTAYE Gina Mariam  BASS BITTAYE GM
# ...        ...                       ...              ...
# 11045  4678919           CHOULOUTE Mayah      CHOULOUTE M
# 11054  4846949            NIJJAR Jasneet         NIJJAR J
# 11056  4849459       PERMATAHANI Azzahra    PERMATAHANI A
# 11060  4966765       ADAMOPOULOU Ariadni    ADAMOPOULOU A
# 11073  4969017            HAN Phone Pyae           HAN PP
#
#                         name_tv  gender function country_code    country  \
# 0              Artur ALEKSANYAN    Male  Athlete          ARM    Armenia
# 3             Arsen HARUTYUNYAN    Male  Athlete          ARM    Armenia
# ...

# %%
df_athletes["hero"].isnull().any()
# Out:
# np.True_

# %%
df_athletes["hero"].isnull().all()
# Out:
# np.False_

# %% [markdown]
# ### Remoção de dados faltantes

# %%
df_athletes.dropna().shape
# Out:
# (11, 38)

# %%
df_athletes.dropna(subset=["hero", "influence"]).shape
# Out:
# (1277, 38)

# %%
df_athletes.dropna(axis=1).shape
# Out:
# (11110, 16)

# %%
df_athletes.dropna(axis=1)
# Out:
#           code                        name     name_short  \
# 0      1532872            ALEKSANYAN Artur   ALEKSANYAN A
# 1      1532873              AMOYAN Malkhas       AMOYAN M
# 2      1532874             GALSTYAN Slavik     GALSTYAN S
# 3      1532944           HARUTYUNYAN Arsen  HARUTYUNYAN A
# 4      1532945             TEVANYAN Vazgen     TEVANYAN V
# ...        ...                         ...            ...
# 11105  4982175               JOSEPH Elijah       JOSEPH E
# 11106  4982762             HOMAN Khrystyna        HOMAN K
# 11107  4983537  CHELANGAT Annet Chemengich   CHELANGAT AC
# 11108  4986655              ADA ETO Sefora      ADA ETO S
# 11109  9460001             LIUZZI Emanuela       LIUZZI E
#
#                           name_tv  gender function country_code  \
# 0                Artur ALEKSANYAN    Male  Athlete          ARM
# 1                  Malkhas AMOYAN    Male  Athlete          ARM
# 2                 Slavik GALSTYAN    Male  Athlete          ARM
# ...

# %%
df_missing_values_cols = (df_athletes.isnull().sum() / df_athletes.shape[0])* 100

# %%
df_missing_values_cols.sort_values(ascending=False)
# Out:
# ritual                92.295230
# other_sports          90.486049
# influence             80.639064
# sporting_relatives    77.353735
# philosophy            74.986499
# nickname              73.330333
# hero                  70.189019
# hobbies               62.187219
# education             50.216022
# family                50.000000
# reason                47.452745
# residence_place       38.865887
# coach                 26.084608
# residence_country     25.508551
# birth_place           21.575158
# birth_country         14.842484
# occupation            13.852385
# lang                   4.698470
# nationality_full       0.171017
# nationality_code       0.171017
# nationality            0.171017
# weight                 0.162016
# function               0.000000
# gender                 0.000000
# name_tv                0.000000
# name_short             0.000000
# name                   0.000000
# code                   0.000000
# country_code           0.000000
# ...

# %%
df_athletes.shape
# Out:
# (11110, 38)

# %%
cols_to_drop = df_missing_values_cols[df_missing_values_cols > 80].index

# %%
df_athletes.shape
# Out:
# (11110, 38)

# %%
df_athletes.drop(cols_to_drop, axis=1).shape
# Out:
# (11110, 35)

# %%
df_amazon.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# moeda                  0
# Categoria_Macro        0
# dtype: int64

# %%
df_amazon.shape
# Out:
# (1433, 18)

# %%
df_missing_values_rows = (df_athletes.isnull().sum(axis=1) / df_athletes.shape[1])* 100

# %%
df_missing_values_rows
# Out:
# 0         7.894737
# 1        28.947368
# 2        36.842105
# 3        15.789474
# 4        23.684211
#            ...
# 11105    39.473684
# 11106    10.526316
# 11107    36.842105
# 11108    31.578947
# 11109    50.000000
# Length: 11110, dtype: float64

# %%
df_missing_values_rows[df_missing_values_rows > 30]
# Out:
# 2        36.842105
# 20       39.473684
# 21       31.578947
# 22       47.368421
# 23       39.473684
#            ...
# 11103    31.578947
# 11105    39.473684
# 11107    36.842105
# 11108    31.578947
# 11109    50.000000
# Length: 2673, dtype: float64

# %%
rows_to_drop = df_missing_values_rows[df_missing_values_rows > 30].index

# %%
df_athletes.drop(rows_to_drop, axis=0).shape
# Out:
# (8437, 38)

# %% [markdown]
# ### Preenchimento de dados faltantes

# %%
df_amazon.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ¹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ¹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ¹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ¹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ¹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ¹1,099                 64%    4.2       24,269
# ...

# %%
df_amazon[df_amazon["rating_count"].isnull()]
# Out:
#      product_id                                       product_name  \
# 279  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 321  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 279  Computers&Accessories|Accessories&Peripherals|...             ¹199
# 321  Computers&Accessories|Accessories&Peripherals|...             ¹249
#
#     actual_price discount_percentage rating rating_count  \
# 279         ¹999                 80%    3.0          NaN
# 321         ¹999                 75%    5.0          NaN
#
#                                          about_product  \
# 279  USB C to C Cable: This cable has type C connec...
# 321  =[The Fastest Charge] - This iPhone USB C cab...
#
#                           user_id    user_name      review_id  \
# 279  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 321  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
# ...

# %%
df_amazon["rating_count_preenchido"] = df_amazon["rating_count"].fillna(1)

# %%
df_amazon[df_amazon["rating_count"].isnull()]
# Out:
#      product_id                                       product_name  \
# 279  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 321  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 279  Computers&Accessories|Accessories&Peripherals|...             ¹199
# 321  Computers&Accessories|Accessories&Peripherals|...             ¹249
#
#     actual_price discount_percentage rating rating_count  \
# 279         ¹999                 80%    3.0          NaN
# 321         ¹999                 75%    5.0          NaN
#
#                                          about_product  \
# 279  USB C to C Cable: This cable has type C connec...
# 321  =[The Fastest Charge] - This iPhone USB C cab...
#
#                           user_id    user_name      review_id  \
# 279  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 321  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
# ...

# %%
df_athletes["hero"]
# Out:
# 0        Footballer Zinedine Zidane (FRA), World Cup wi...
# 1                                                      NaN
# 2                                                      NaN
# 3        Wrestler Armen Nazaryan (ARM, BUL), two-time O...
# 4                                                      NaN
#                                ...
# 11105                                                  NaN
# 11106                                                  NaN
# 11107                                                  NaN
# 11108                                                  NaN
# 11109                                                  NaN
# Name: hero, Length: 11110, dtype: object

# %%
df_athletes["hero"] = df_athletes["hero"].fillna("Nao informado")

# %%
### OU df_athletes["hero"].fillna("Nao informado", inplace=True)

# %%
df_athletes["hero"]
# Out:
# 0        Footballer Zinedine Zidane (FRA), World Cup wi...
# 1                                            Nao informado
# 2                                            Nao informado
# 3        Wrestler Armen Nazaryan (ARM, BUL), two-time O...
# 4                                            Nao informado
#                                ...
# 11105                                        Nao informado
# 11106                                        Nao informado
# 11107                                        Nao informado
# 11108                                        Nao informado
# 11109                                        Nao informado
# Name: hero, Length: 11110, dtype: object

# %%
df_athletes.loc[df_athletes["height"] == 0, "height"] = None  ### somente coluna height onde o valor eh 0

# %%
df_athletes[df_athletes["height"].isnull()]
# Out:
#           code                      name      name_short  \
# 0      1532872          ALEKSANYAN Artur    ALEKSANYAN A
# 1      1532873            AMOYAN Malkhas        AMOYAN M
# 2      1532874           GALSTYAN Slavik      GALSTYAN S
# 3      1532944         HARUTYUNYAN Arsen   HARUTYUNYAN A
# 4      1532945           TEVANYAN Vazgen      TEVANYAN V
# ...        ...                       ...             ...
# 11077  4974188  LOBALU Dominic Lokinyomo       LOBALU DL
# 11086  4978246           MILLAR Isabella        MILLAR I
# 11103  4979790       INSIXIENGMAY Steven  INSIXIENGMAY S
# 11106  4982762           HOMAN Khrystyna         HOMAN K
# 11109  9460001           LIUZZI Emanuela        LIUZZI E
#
#                         name_tv  gender function country_code  \
# 0              Artur ALEKSANYAN    Male  Athlete          ARM
# 1                Malkhas AMOYAN    Male  Athlete          ARM
# 2               Slavik GALSTYAN    Male  Athlete          ARM
# ...

# %%
df_athletes["height"].fillna(df_athletes["height"].mean())
# Out:
# 0        178.965144
# 1        178.965144
# 2        178.965144
# 3        178.965144
# 4        178.965144
#             ...
# 11105    177.000000
# 11106    178.965144
# 11107    174.000000
# 11108    165.000000
# 11109    178.965144
# Name: height, Length: 11110, dtype: float64

# %%
df_athletes["height"].fillna(df_athletes["height"].median())
# Out:
# 0        178.0
# 1        178.0
# 2        178.0
# 3        178.0
# 4        178.0
#          ...
# 11105    177.0
# 11106    178.0
# 11107    174.0
# 11108    165.0
# 11109    178.0
# Name: height, Length: 11110, dtype: float64

# %%
df_athletes["height"].mode()
# Out:
# 0    170.0
# Name: height, dtype: float64

# %%
df_athletes["height"].mode().iloc[0]
# Out:
# np.float64(170.0)

# %%
df_athletes["height"].fillna(df_athletes["height"].mode().iloc[0])
# Out:
# 0        170.0
# 1        170.0
# 2        170.0
# 3        170.0
# 4        170.0
#          ...
# 11105    177.0
# 11106    170.0
# 11107    174.0
# 11108    165.0
# 11109    170.0
# Name: height, Length: 11110, dtype: float64

# %%
df_athletes["height"].fillna(method="ffill").fillna(method="bfill")
# Out:
# C:\Users\bianc\AppData\Local\Temp\ipykernel_94536\4081416807.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_athletes["height"].fillna(method="ffill").fillna(method="bfill")
# 0        162.0
# 1        162.0
# 2        162.0
# 3        162.0
# 4        162.0
#          ...
# 11105    177.0
# 11106    177.0
# 11107    174.0
# 11108    165.0
# 11109    165.0
# Name: height, Length: 11110, dtype: float64

# %% [markdown]
# ### Outliers

# %% [markdown]
# #### Boxplot

# %%
df_positive_height = df_athletes[df_athletes["height"] > 0]

# %%
df_positive_height.shape
# Out:
# (5078, 38)

# %%
df_positive_height["height"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# * IQR = Q3 - Q1
# * Limite Inferior = Q1 - 1.5 * IQR
# * Limite Superiro = Q3 + 1.5 * IQR

# %%
df_col = df_positive_height["height"]

# %%
df_col
# Out:
# 5        162.0
# 7        161.0
# 8        178.0
# 12       183.0
# 25       170.0
#          ...
# 11102    177.0
# 11104    168.0
# 11105    177.0
# 11107    174.0
# 11108    165.0
# Name: height, Length: 5078, dtype: float64

# %%
Q1 = df_col.quantile(0.25)
Q3 = df_col.quantile(0.75)

# %%
Q1
# Out:
# np.float64(170.0)

# %%
Q3
# Out:
# np.float64(187.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# np.float64(17.0)

# %%
limite_superior = Q3 + 1.5 * IQR
limite_inferior = Q1 - 1.5 * IQR
print(f" Limite Superior: {limite_superior}, Limite Inferior: {limite_inferior}")
# Out:
#  Limite Superior: 212.5, Limite Inferior: 144.5

# %%
outliers = df_positive_height[(df_positive_height["height"] > limite_superior) | (df_positive_height["height"] < limite_inferior)]

# %%
outliers.shape
# Out:
# (10, 38)

# %% [markdown]
# #### Z-Score

# %%
df_positive_height["height"].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_col
# Out:
# 5        162.0
# 7        161.0
# 8        178.0
# 12       183.0
# 25       170.0
#          ...
# 11102    177.0
# 11104    168.0
# 11105    177.0
# 11107    174.0
# 11108    165.0
# Name: height, Length: 5078, dtype: float64

# %%
df_col.mean()
# Out:
# np.float64(178.9651437573848)

# %%
df_col.std()
# Out:
# np.float64(11.733523018583378)

# %%
df_zscore = (df_col - df_col.mean()) / df_col.std()

# %%
df_zscore
# Out:
# 5       -1.445870
# 7       -1.531095
# 8       -0.082255
# 12       0.343874
# 25      -0.764062
#            ...
# 11102   -0.167481
# 11104   -0.934514
# 11105   -0.167481
# 11107   -0.423159
# 11108   -1.190192
# Name: height, Length: 5078, dtype: float64

# %%
outliers_zscore = df_positive_height[df_zscore.abs() > 3]

# %%
outliers_zscore
# Out:
#           code                  name     name_short               name_tv  \
# 2359   1573633           GOBERT Rudy       GOBERT R           Rudy GOBERT
# 2363   1573639     WEMBANYAMA Victor   WEMBANYAMA V     Victor WEMBANYAMA
# 3267   1894235        BOGUCKI Adrian      BOGUCKI A        Adrian BOGUCKI
# 6159   1925995        CHITUNDU Avell     CHITUNDU A        Avell CHITUNDU
# 8301   1948421          PLAVSIC Uros      PLAVSIC U          Uros PLAVSIC
# 9402   1961275  PAPAGIANNIS Georgios  PAPAGIANNIS G  Georgios PAPAGIANNIS
# 10038  1969115        MALUACH Khaman      MALUACH K        Khaman MALUACH
#
#        gender function country_code      country country_full  nationality  \
# 2359     Male  Athlete          FRA       France       France       France
# 2363     Male  Athlete          FRA       France       France       France
# 3267     Male  Athlete          POL       Poland       Poland       Poland
# ...

# %% [markdown]
# #### Removendo os outliers

# %%
df_positive_height[df_zscore.abs() <= 3]
# Out:
#           code                        name       name_short  \
# 5      1532951               ARENAS Lorena         ARENAS L
# 7      1533136    BASS BITTAYE Gina Mariam  BASS BITTAYE GM
# 8      1533176             CAMARA Ebrahima         CAMARA E
# 12     1533208            MAAROUFOU Hachim      MAAROUFOU H
# 25     1533364              ISMAIL Mohamed         ISMAIL M
# ...        ...                         ...              ...
# 11102  4979624        PAPAMICHAIL Despoina    PAPAMICHAIL D
# 11104  4980004            van de WIEL Anne    van de WIEL A
# 11105  4982175               JOSEPH Elijah         JOSEPH E
# 11107  4983537  CHELANGAT Annet Chemengich     CHELANGAT AC
# 11108  4986655              ADA ETO Sefora        ADA ETO S
#
#                           name_tv  gender function country_code  \
# 5                   Lorena ARENAS  Female  Athlete          COL
# 7        Gina Mariam BASS BITTAYE  Female  Athlete          GAM
# ...

# %% [markdown]
# #### Suavizando os outliers

# %%
limite_superior = df_positive_height["height"].quantile(0.95)
limite_superior
# Out:
# np.float64(199.14999999999964)

# %%
limite_inferior = df_positive_height["height"].quantile(0.05)
limite_inferior
# Out:
# np.float64(161.0)

# %%
df_positive_height.loc[df_zscore > 3, "height"] = limite_superior

# %%
df_positive_height.loc[df_zscore < -3, "height"] = limite_inferior

# %% [markdown]
# ## Transformando dados categóricos

# %%
path + "/gym_members_exercise_tracking.csv"
# Out:
# 'C:/Users/bianc/OneDrive/Documents/1-Estudos/2-DNC/1-Data Science/1-Material/Materis8-DataCleaning_Wrangling/MichineLearning/DataCW-main/DataCW-main/Datasets/gym_members_exercise_tracking.csv'

# %%
df_gym = pd.read_csv(path + "/gym_members_exercise_tracking.csv")
df_gym.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
df_gym.shape
# Out:
# (973, 15)

# %%
df_gym["Workout_Type"].value_counts()
# Out:
# Workout_Type
# Strength    258
# Cardio      255
# Yoga        239
# HIIT        221
# Name: count, dtype: int64

# %%
df_gym["Workout_Type"].astype("category")
# Out:
# 0          Yoga
# 1          HIIT
# 2        Cardio
# 3      Strength
# 4      Strength
#          ...
# 968    Strength
# 969    Strength
# 970      Cardio
# 971        HIIT
# 972    Strength
# Name: Workout_Type, Length: 973, dtype: category
# Categories (4, object): ['Cardio', 'HIIT', 'Strength', 'Yoga']

# %%
df_gym["Workout_Type"] = df_gym["Workout_Type"].astype("category")

# %%
df_gym["Workout_Type"]
# Out:
# 0          Yoga
# 1          HIIT
# 2        Cardio
# 3      Strength
# 4      Strength
#          ...
# 968    Strength
# 969    Strength
# 970      Cardio
# 971        HIIT
# 972    Strength
# Name: Workout_Type, Length: 973, dtype: category
# Categories (4, object): ['Cardio', 'HIIT', 'Strength', 'Yoga']

# %%
df_gym["Workout_Type"].cat.codes
# Out:
# 0      3
# 1      1
# 2      0
# 3      2
# 4      2
#       ..
# 968    2
# 969    2
# 970    0
# 971    1
# 972    2
# Length: 973, dtype: int8

# %%
df_gym["Workout_Type_Number"] = df_gym["Workout_Type"].cat.codes
