# %% [markdown]
# # 🌟 **Professora Aurora - Projeto Integrado de Data Science**
#
# ## 🚀 **DEFININDO NOSSO PROJETO GUIA**
#
# ### 📊 **Projeto Escolhido: "Otimização Estratégica do iFood"**
#
# **🎯 Por que este projeto?**
#
# Escolhi este projeto porque ele conecta **PERFEITAMENTE** todos os 7 tópicos do módulo de forma prática e realista:
#
# 1. **📈 Relevância Empresarial:** O iFood é uma empresa real com desafios reais de amostragem
# 2. **🔗 Interdisciplinaridade:** Conecta estatística → negócios → tecnologia → tomada de decisão
# 3. **📊 Dados Reais:** Temos uma base real com restaurantes, preços, avaliações, distâncias
# 4. **🎯 Aplicação Prática:** Cada conceito estatístico terá impacto direto no negócio
#
# ### 🏢 **Nosso Papel: Cientistas de Dados do iFood**
#
# **Missão:** Otimizar a plataforma usando amostragem inteligente para:
# - 📍 Expandir para novas regiões
# - 💰 Definir estratégias de preços
# - ⭐ Melhorar experiência do usuário
# - 📊 Reduzir custos de pesquisa
#
# ---
#
# ## 📋 **SEQUÊNCIA PEDAGÓGICA CORRIGIDA**
#
# Você está **ABSOLUTAMENTE CERTO**! A ordem faz total sentido pedagógico:
#
# | # | **Aula DNC** | **Tópico** | **Por que nesta ordem** |
# |---|--------------|------------|-------------------------|
# | 1 | **Aula 1** | Populações e Amostras | Base conceitual - definir vocabulário |
# | 2 | **Aula 2** | Tipos de Amostragem | Como coletar dados corretamente |
# | 3 | **Aula 3** | Viés na Amostragem | Armadilhas a evitar |
# | 4 | **Aula 4** | Distribuições Amostrais | Entender variabilidade |
# | 5 | **Aula 5** | Teorema do Limite Central | Justificativa matemática |
# | 6 | **Aula 6** | Tamanho Amostral | Quanto coletar (custo vs precisão) |
# | 7 | **Aula 7** | Avaliação em Python | Consolidação prática |
#
# ---
#
# ## 📋 **PROJETO: "Otimização Estratégica do iFood"**
#
# ### 🏢 **CONTEXTO EMPRESARIAL**
#
# **Situação:** Você é Cientista de Dados Jr. no iFood. A empresa quer expandir operações e otimizar custos, mas precisa tomar decisões baseadas em dados **SEM** gastar milhões em pesquisas com toda a base.
#
# **🎯 Problema Central:** *"Como usar amostragem inteligente para tomar decisões estratégicas precisas com menor custo e risco?"*
#
# ---
#
# ## 🗺️ **ROADMAP COMPLETO - 7 ENTREGAS**
#
# ### **📦 ENTREGA 1 - Aula 1 DNC (População vs Amostra)**
# **🎯 Objetivo:** Definir nossa população e entender o que queremos medir
#
# **📋 O que vamos fazer:**
# - Explorar a base completa do iFood (nossa **população**)
# - Identificar **parâmetros** importantes (preço médio, tempo de entrega, rating)
# - Extrair uma **amostra** e comparar **estatísticas** vs **parâmetros**
#
# **📊 Entregável:**
# ```markdown
# ## Relatório 1: Mapeamento da População iFood
# - Tamanho da população: X restaurantes
# - Parâmetros-chave identificados
# - Primeira amostra piloto e comparação
# ```
#
# ---
#
# ### **📦 ENTREGA 2 - Aula 2 DNC (Tipos de Amostragem)**
# **🎯 Objetivo:** Escolher o melhor método para diferentes cenários
#
# **📋 O que vamos fazer:**
# - **Amostragem Simples:** Para análise geral de preços
# - **Amostragem Estratificada:** Por categoria de comida (Pizza, Brasileira, etc.)
# - **Comparar métodos:** Qual dá resultados mais representativos?
#
# **📊 Entregável:**
# ```markdown
# ## Relatório 2: Estratégias de Amostragem
# - Método recomendado para cada tipo de análise
# - Código Python para cada método
# - Comparação de representatividade
# ```
#
# ---
#
# ### **📦 ENTREGA 3 - Aula 3 DNC (Viés na Amostragem)**
# **🎯 Objetivo:** Identificar e evitar armadilhas nos dados
#
# **📋 O que vamos fazer:**
# - **Detectar viés geográfico:** Restaurantes só de uma região?
# - **Identificar viés de preço:** Só restaurantes caros/baratos?
# - **Corrigir vieses:** Técnicas para amostra mais justa
#
# **📊 Entregável:**
# ```markdown
# ## Relatório 3: Auditoria de Vieses
# - Lista de vieses identificados na base
# - Impacto de cada viés nas decisões
# - Plano de correção implementado
# ```
#
# ---
#
# ### **📦 ENTREGA 4 - Aula 4 DNC (Distribuições Amostrais)**
# **🎯 Objetivo:** Entender a variabilidade das nossas estimativas
#
# **📋 O que vamos fazer:**
# - Simular **100 amostras** diferentes
# - Plotar distribuição das **médias de preço**
# - Calcular **intervalo de confiança** para nossas estimativas
#
# **📊 Entregável:**
# ```markdown
# ## Relatório 4: Análise de Variabilidade
# - Gráfico da distribuição das médias amostrais
# - Intervalo de confiança para parâmetros-chave
# - Recomendação de precisão esperada
# ```
#
# ---
#
# ### **📦 ENTREGA 5 - Aula 5 DNC (Teorema do Limite Central)**
# **🎯 Objetivo:** Validar que podemos usar distribuição normal
#
# **📋 O que vamos fazer:**
# - Testar TLC com dados de **tempo de entrega** (não-normal)
# - Mostrar como médias ficam normais mesmo com dados "estranhos"
# - Aplicar testes estatísticos baseados em normalidade
#
# **📊 Entregável:**
# ```markdown
# ## Relatório 5: Validação Estatística
# - Prova visual do TLC com nossos dados
# - Justificativa para usar testes paramétricos
# - Limites de aplicação do TLC
# ```
#
# ---
#
# ### **📦 ENTREGA 6 - Aula 6 DNC (Tamanho Amostral)**
# **🎯 Objetivo:** Calcular o tamanho ideal para cada análise
#
# **📋 O que vamos fazer:**
# - **Cenário A:** Pesquisa de satisfação (quantos clientes entrevistar?)
# - **Cenário B:** Teste A/B de nova interface (quantos usuários?)
# - **Análise custo-benefício:** Precisão vs investimento
#
# **📊 Entregável:**
# ```markdown
# ## Relatório 6: Dimensionamento Estratégico
# - Tamanho amostral para cada tipo de pesquisa
# - Calculadora Python para futuros projetos
# - Análise de ROI por tamanho de amostra
# ```
#
# ---
#
# ### **📦 ENTREGA 7 - Aula 7 DNC (Avaliação em Python)**
# **🎯 Objetivo:** Consolidar tudo em um experimento real
#
# **📋 O que vamos fazer:**
# - **Experimento A/B:** Testar nova estratégia de recomendação
# - **Aplicar tudo:** Amostragem + controle de viés + tamanho ideal
# - **Dashboard final:** Resultados e recomendações
#
# **📊 Entregável:**
# ```markdown
# ## Relatório Final: Experimento Completo
# - Metodologia completa aplicada
# - Resultados do teste A/B
# - Recomendações estratégicas para o iFood
# - Toolkit Python para futuros projetos
# ```
#
# ---
#
# ## 🎯 **PRODUTO FINAL**
#
# ### **📈 O que você terá ao final:**
#
# 1. **🧠 Conhecimento Sólido:** Domínio completo de amostragem estatística
# 2. **🐍 Toolkit Python:** Códigos reutilizáveis para qualquer projeto
# 3. **📊 Portfolio:** 7 relatórios profissionais para mostrar a empregadores
# 4. **🏢 Experiência Real:** Simulação completa de projeto empresarial
#
# ### **💼 Competências Desenvolvidas:**
# - ✅ Análise exploratória de dados
# - ✅ Design de experimentos
# - ✅ Controle de qualidade estatística
# - ✅ Comunicação de resultados
# - ✅ Tomada de decisão baseada em dados
#
#
# ---
#
# > **💡 Dica da Aurora:** *"Este projeto vai simular exatamente o que você faria como cientista de dados em uma empresa real. Cada conceito estatístico terá aplicação prática imediata!"*
# ---

# %% [markdown]
# # 🌟 **ENTREGA 1 - Aula 1 DNC: População vs Amostra**

# %% [markdown]
# ## 📊 **Mapeamento da População iFood**
#
# ### **🎯 Objetivo desta Entrega:**
# Definir nossa população e entender o que queremos medir como verdadeiros cientistas de dados do iFood.
#
# ---
#
# ## **PASSO 1: Carregando Nossa População**
#
# Vamos começar com o primeiro micro-bloco de código:
#
# ```python
# # 🔍 BLOCO 1: Importando as ferramentas essenciais
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# ```
#
# ### 🧠 **Anatomia do Código - Linha por Linha:**
#
# **Linha 1:** `import pandas as pd`
# - **O que faz:** Importa a biblioteca Pandas
# - **Por que 'pd':** Convenção universal para economizar digitação
# - **Analogia:** Como ter uma planilha Excel super inteligente no Python
#
# **Linha 2:** `import numpy as np`
# - **O que faz:** Importa biblioteca para cálculos matemáticos
# - **Por que 'np':** Padrão da comunidade científica
# - **Analogia:** Nossa calculadora científica para estatística
#
# **Linha 3:** `import matplotlib.pyplot as plt`
# - **O que faz:** Importa ferramenta para criar gráficos
# - **Por que 'plt':** Convenção para plotting (plotagem)
# - **Analogia:** Nosso pincel e tinta para desenhar insights
#
# ---
# 💡 Dica da Aurora: "Essas três bibliotecas são o 'trio sagrado' de qualquer cientista de dados. Você vai usá-las em 99% dos projetos!"
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 🌟 **PASSO 2: Carregando os Dados do iFood**

# %% [markdown]
# Agora vamos carregar nossa **população** completa de restaurantes:
#
# ```python
# # 🔍 BLOCO 2: Carregando nossa população de dados
# df = pd.read_csv('ifood_df.csv')
# ```
#
# ### 🧠 **Anatomia do Código:**
#
# **`df = pd.read_csv('ifood_df.csv')`**
# - **df:** Nome da variável (convenção para "dataframe")
# - **pd.read_csv():** Função do pandas para ler arquivos CSV
# - **'ifood_df.csv':** Nome do arquivo com nossos dados
# - **Analogia:** Como abrir uma planilha Excel gigante no Python
#
# ---
#
# ## **PASSO 3: Primeira Exploração da População**
#
# Vamos dar uma "espiada" nos nossos dados:
#
# ```python
# # 🔍 BLOCO 3: Conhecendo nossa população
# print("🏢 POPULAÇÃO COMPLETA DO iFOOD")
# print("=" * 40)
# print(f"📊 Total de restaurantes: {len(df)}")
# print(f"📋 Colunas disponíveis: {len(df.columns)}")
# print("\n🔍 Primeiras 5 linhas:")
# print(df.head())
# ```
#
# ### 🧠 **Anatomia do Código - Linha por Linha:**
#
# **`len(df)`:** Conta quantas linhas (restaurantes) temos
# **`len(df.columns)`:** Conta quantas colunas (características) temos
# **`df.head()`:** Mostra as primeiras 5 linhas para darmos uma olhada
# **`print(f"...")`:** Formatação bonita para mostrar resultados
#
# ---

# %%
# 🔍 BLOCO 2: Carregando nossa população de dados
df = pd.read_csv("C:/Users/bianc/OneDrive/Documents/1-Estudos/2-DNC/1-Data Science/3-GitHub/DNC-DataScience/Materia_7-Estatistica/Aulas/base_ifood_limpa_Simplificada_V02.csv")

# %%
# 🔍 BLOCO 3: Conhecendo nossa população
print("🏢 POPULAÇÃO COMPLETA DO iFOOD")
print("=" * 40)
print(f"📊 Total de restaurantes: {len(df)}")
print(f"📋 Colunas disponíveis: {len(df.columns)}")
print("\n🔍 Primeiras 5 linhas:")
df.head()
# Out:
# 🏢 POPULAÇÃO COMPLETA DO iFOOD
# ...
# 📊 Total de restaurantes: 188987
# 📋 Colunas disponíveis: 1
#
# 🔍 Primeiras 5 linhas:
#   id;availableForScheduling;category;delivery_fee;delivery_time;distance;minimumOrderValue;price_range;rating
# 0     0;False;Marmita;3.99;27;1.22;10.0;CHEAPEST;0.0
# 1        1;False;Açaí;7.99;61;4.96;10.0;CHEAPEST;0.0
# 2     2;False;Bebidas;11.99;70;8.35;5.0;MODERATE;0.0
# 3     3;False;Carnes;16.49;63;6.35;20.0;CHEAPEST;0.0
# 4  4;False;Brasileira;11.99;58;5.22;20.0;CHEAPEST...

# %% [markdown]
# # 🌟 **PASSO 2 CORRIGIDO: Carregamento Profissional**

# %% [markdown]
# ## 🎯 **Problemas Identificados e Soluções:**
#
# 1. **🔍 Separador:** CSV brasileiro usa ";" ao invés de ","
# 2. **🛡️ Segurança:** Devemos abrir/fechar arquivos com segurança
# 3. **📊 Encoding:** Arquivos brasileiros podem ter acentos (UTF-8)
#
# ---
#
# ## **VERSÃO PROFISSIONAL:**
#
# ```python
# # 🔍 BLOCO 2: Carregamento PROFISSIONAL dos dados
# import os
#
# # Verificar se arquivo existe
# if os.path.exists('ifood_df.csv'):
#     try:
#         # Carregamento seguro com parâmetros brasileiros
#         df = pd.read_csv('ifood_df.csv',
#                         sep=';',           # Separador brasileiro
#                         encoding='utf-8',  # Acentos brasileiros
#                         decimal=',')       # Decimal brasileiro
#         print("✅ Arquivo carregado com sucesso!")
#     except Exception as e:
#         print(f"❌ Erro ao carregar arquivo: {e}")
# else:
#     print("❌ Arquivo 'ifood_df.csv' não encontrado!")
# ```
#
# ### 🧠 **Anatomia do Código Profissional:**
#
# **`os.path.exists()`:** Verifica se arquivo existe antes de tentar abrir
# **`try/except`:** Captura erros de forma elegante
# **`sep=';'`:** Define separador como ponto-e-vírgula (padrão brasileiro)
# **`encoding='utf-8'`:** Lida com acentos e caracteres especiais
# **`decimal=','`:** Reconhece vírgula como separador decimal
#
# ---
#
# ## **ALTERNATIVA: Context Manager (Mais Seguro)**
#
# ```python
# # 🔍 BLOCO 2 ALTERNATIVO: Com context manager
# try:
#     with open('ifood_df.csv', 'r', encoding='utf-8') as file:
#         df = pd.read_csv(file,
#                         sep=';',
#                         decimal=',')
#     print("✅ Arquivo carregado e fechado com segurança!")
# except FileNotFoundError:
#     print("❌ Arquivo não encontrado!")
# except UnicodeDecodeError:
#     print("❌ Problema de encoding - tentando latin-1...")
#     df = pd.read_csv('ifood_df.csv', sep=';', encoding='latin-1')
# except Exception as e:
#     print(f"❌ Erro inesperado: {e}")
# ```
#
# ### 🧠 **Por que Context Manager é Melhor:**
#
# **`with open()`:** Garante que arquivo seja fechado automaticamente
# **Múltiplos except:** Trata diferentes tipos de erro
# **Fallback encoding:** Se UTF-8 falhar, tenta latin-1
#
# ---

# %%
# 🔍 BLOCO 2 ALTERNATIVO: Com context manager
try:
    with open('C:/Users/bianc/OneDrive/Documents/1-Estudos/2-DNC/1-Data Science/3-GitHub/DNC-DataScience/Materia_7-Estatistica/Aulas/base_ifood_limpa_Simplificada.csv', 'r', encoding='utf-8') as file:
        df = pd.read_csv(file, 
                        sep=';', 
                        decimal=',')
    print("✅ Arquivo carregado e fechado com segurança!")
except FileNotFoundError:
    print("❌ Arquivo não encontrado!")
except UnicodeDecodeError:
    print("❌ Problema de encoding - tentando latin-1...")
    df = pd.read_csv('ifood_df.csv', sep=';', encoding='latin-1')
except Exception as e:
    print(f"❌ Erro inesperado: {e}")
# Out:
# ✅ Arquivo carregado e fechado com segurança!

# %%
# 🔍 BLOCO 3 ALTERNATIVO: Conhecendo nossa população
print("🏢 POPULAÇÃO COMPLETA DO iFOOD")
print("=" * 40)
print(f"📊 Total de restaurantes: {len(df)}")
print(f"📋 Colunas disponíveis: {len(df.columns)}")
print("\n🔍 Primeiras 5 linhas:")
df.head()
# Out:
# 🏢 POPULAÇÃO COMPLETA DO iFOOD
# ...
# 📊 Total de restaurantes: 188987
# 📋 Colunas disponíveis: 9
#
# 🔍 Primeiras 5 linhas:
#    id  availableForScheduling    category delivery_fee  delivery_time  \
# 0   0                   False     Marmita         3.99             27
# 1   1                   False        Açaí         7.99             61
# 2   2                   False     Bebidas        11.99             70
# 3   3                   False      Carnes        16.49             63
# 4   4                   False  Brasileira        11.99             58
#
#   distance minimumOrderValue price_range rating
# 0     1.22              10.0    CHEAPEST    0.0
# 1     4.96              10.0    CHEAPEST    0.0
# 2     8.35               5.0    MODERATE    0.0
# 3     6.35              20.0    CHEAPEST    0.0
# 4     5.22              20.0    CHEAPEST    0.0

# %% [markdown]
# # 🌟 **PASSO 3: Primeira Exploração da População (Versão Profissional)**

# %% [markdown]
# Agora vamos explorar nossa população com **análise crítica profissional**:
#
# ```python
# # 🔍 BLOCO 3: Exploração PROFISSIONAL da população
# def explorar_dataset(df):
#     """
#     Função para exploração completa e profissional do dataset
#     """
#     print("🏢 POPULAÇÃO COMPLETA DO iFOOD")
#     print("=" * 50)
#
#     # Informações básicas
#     print(f"📊 Total de restaurantes (população): {len(df):,}")
#     print(f"📋 Total de características (colunas): {len(df.columns)}")
#     print(f"💾 Uso de memória: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
#
#     # Verificação de qualidade dos dados
#     print(f"\n🔍 QUALIDADE DOS DADOS:")
#     print(f"❌ Valores nulos: {df.isnull().sum().sum()}")
#     print(f"🔄 Linhas duplicadas: {df.duplicated().sum()}")
#
#     # Tipos de dados
#     print(f"\n📝 TIPOS DE DADOS:")
#     for col, dtype in df.dtypes.items():
#         null_count = df[col].isnull().sum()
#         print(f"   {col}: {dtype} (nulos: {null_count})")
#
#     return df.head()
#
# # Executar exploração
# primeiras_linhas = explorar_dataset(df)
# print(f"\n🔍 AMOSTRA DOS DADOS:")
# print(primeiras_linhas)
# ```
#
# ### 🧠 **Anatomia do Código Profissional:**
#
# - **`def explorar_dataset(df):`** Função reutilizável (DRY principle)
# - **`{len(df):,}`** Formatação com separador de milhares
# - **`memory_usage(deep=True)`** Análise real do uso de memória
# - **`df.isnull().sum().sum()`** Contagem total de valores nulos
# - **`df.duplicated().sum()`** Detecção de dados duplicados
# - **`df.dtypes.items()`** Análise dos tipos de dados por coluna
# ---
# **❓ Pergunta da Aurora:** *"Ficou claro por que essa exploração é mais profissional? Ela nos dá insights sobre qualidade dos dados, não apenas uma 'espiada'. Posso seguir para identificar nossos parâmetros populacionais?"*
#
# ---
# > **💡 Dica da Aurora:** *"Sempre analise a qualidade dos dados ANTES de fazer qualquer estatística. Dados ruins = insights ruins!"*
# ---

# %%
def explorar_dataset(df):
    print("🏢 POPULAÇÃO COMPLETA DO iFOOD")
    print("=" * 50)
    
    print(f"📊 Total de restaurantes (população): {len(df):,}")
    print(f"📋 Total de características (colunas): {len(df.columns)}")
    print(f"💾 Uso de memória: {df.memory_usage(deep=True).sum()/ 1024**2:.2f} MB")
    
    
    print(f"\n🔍 QUALIDADE DOS DADOS:")
    print(f"❌ Valores nulos: {df.isnull().sum().sum()}")
    print(f"🔄 Linhas duplicadas: {df.duplicated().sum()}")
    
    print(f"\n📝 TIPOS DE DADOS:")
    for col, dtype in df.dtypes.items():
        null_count = df[col].isnull().sum()
        print(f"   {col}: {dtype} (nulos: {null_count})")
    
    return df.head()

# %%
primeiras_linhas = explorar_dataset(df)
print(f"\n🔍 AMOSTRA DOS DADOS:")
print(primeiras_linhas)
# Out:
# 🏢 POPULAÇÃO COMPLETA DO iFOOD
# ...
# 📊 Total de restaurantes (população): 188,987
# 📋 Total de características (colunas): 9
# 💾 Uso de memória: 63.14 MB
#
# 🔍 QUALIDADE DOS DADOS:
# ❌ Valores nulos: 0
# 🔄 Linhas duplicadas: 0
#
# 📝 TIPOS DE DADOS:
#    id: int64 (nulos: 0)
#    availableForScheduling: bool (nulos: 0)
#    category: object (nulos: 0)
#    delivery_fee: object (nulos: 0)
#    delivery_time: int64 (nulos: 0)
#    distance: object (nulos: 0)
#    minimumOrderValue: object (nulos: 0)
#    price_range: object (nulos: 0)
#    rating: object (nulos: 0)
#
# 🔍 AMOSTRA DOS DADOS:
#    id  availableForScheduling    category delivery_fee  delivery_time  \
# 0   0                   False     Marmita         3.99             27
# 1   1                   False        Açaí         7.99             61
# 2   2                   False     Bebidas        11.99             70
# 3   3                   False      Carnes        16.49             63
# ...

# %% [markdown]
# # 🌟 **RESPOSTAS ÀS PERGUNTAS TÉCNICAS**

# %% [markdown]
# ## 🎯 **PERGUNTA 1: Por que dividir por 1024?**
#
# ### **📊 Conversão de Bytes para Megabytes:**
#
# ```python
# # 🔍 DEMONSTRAÇÃO: Como funciona a conversão
# print("📏 CONVERSÃO DE UNIDADES DE MEMÓRIA:")
# print("=" * 40)
#
# # Exemplo com um número
# bytes_exemplo = 2048576  # bytes
#
# print(f"🔢 Valor original: {bytes_exemplo:,} bytes")
# print(f"📐 1024¹ (KB): {bytes_exemplo / 1024:.2f} KB")
# print(f"📐 1024² (MB): {bytes_exemplo / 1024**2:.2f} MB")
# print(f"📐 1024³ (GB): {bytes_exemplo / 1024**3:.2f} GB")
#
# print("\n🧮 EXPLICAÇÃO:")
# print("1 KB = 1024 bytes")
# print("1 MB = 1024 KB = 1024² bytes = 1,048,576 bytes")
# print("1 GB = 1024 MB = 1024³ bytes")
# ```
#
# ### **🧠 Por que 1024 e não 1000?**
# - **💻 Sistema binário:** Computadores trabalham em base 2
# - **🔢 2¹⁰ = 1024:** Potência de 2 mais próxima de 1000
# - **📏 Padrão da indústria:** Sempre usamos 1024 para memória
#
# ---
#
# ## 🎯 **PERGUNTA 2: Por que dois .sum()?**
#
# ### **📊 Demonstração do Duplo .sum():**
#
# ```python
# # 🔍 DEMONSTRAÇÃO: Por que precisamos de dois .sum()
# import pandas as pd
# import numpy as np
#
# # Criando exemplo didático
# dados_exemplo = {
#     'nome': ['João', 'Maria', None, 'Pedro'],
#     'idade': [25, None, 30, 35],
#     'cidade': ['SP', 'RJ', 'MG', None]
# }
# df_exemplo = pd.DataFrame(dados_exemplo)
#
# print("📋 DATASET DE EXEMPLO:")
# print(df_exemplo)
# print("\n" + "="*40)
#
# print("🔍 PASSO A PASSO:")
# print("1️⃣ df.isnull() - Matriz True/False:")
# print(df_exemplo.isnull())
#
# print("\n2️⃣ df.isnull().sum() - Soma por COLUNA:")
# print(df_exemplo.isnull().sum())
#
# print("\n3️⃣ df.isnull().sum().sum() - Soma TOTAL:")
# print(df_exemplo.isnull().sum().sum())
# ```
#
# ### **🧠 Anatomia do Duplo .sum():**
#
# - **`df.isnull()`:** Retorna matriz True/False para cada célula
# - **`df.isnull().sum()`:** Primeiro .sum() conta nulos **por coluna**
# - **`df.isnull().sum().sum()`:** Segundo .sum() soma **todas as colunas**
#
# ---

# %%
# 🔍 DEMONSTRAÇÃO: Como funciona a conversão
print("📏 CONVERSÃO DE UNIDADES DE MEMÓRIA:")
print("=" * 40)

# Exemplo com um número
bytes_exemplo = 2048576  # bytes

print(f"🔢 Valor original: {bytes_exemplo:,} bytes")
print(f"📐 1024¹ (KB): {bytes_exemplo / 1024:.2f} KB")
print(f"📐 1024² (MB): {bytes_exemplo / 1024**2:.2f} MB")
print(f"📐 1024³ (GB): {bytes_exemplo / 1024**3:.2f} GB")

print("\n🧮 EXPLICAÇÃO:")
print("1 KB = 1024 bytes")
print("1 MB = 1024 KB = 1024² bytes = 1,048,576 bytes")
print("1 GB = 1024 MB = 1024³ bytes")
# Out:
# 📏 CONVERSÃO DE UNIDADES DE MEMÓRIA:
# ...
# 🔢 Valor original: 2,048,576 bytes
# 📐 1024¹ (KB): 2000.56 KB
# 📐 1024² (MB): 1.95 MB
# 📐 1024³ (GB): 0.00 GB
#
# 🧮 EXPLICAÇÃO:
# 1 KB = 1024 bytes
# 1 MB = 1024 KB = 1024² bytes = 1,048,576 bytes
# 1 GB = 1024 MB = 1024³ bytes

# %%
# 🔍 DEMONSTRAÇÃO: Por que precisamos de dois .sum()
import pandas as pd
import numpy as np

# Criando exemplo didático
dados_exemplo = {
    'nome': ['João', 'Maria', None, 'Pedro'],
    'idade': [25, None, 30, 35],
    'cidade': ['SP', 'RJ', 'MG', None]
}
df_exemplo = pd.DataFrame(dados_exemplo)

print("📋 DATASET DE EXEMPLO:")
print(df_exemplo)
print("\n" + "="*40)

print("🔍 PASSO A PASSO:")
print("1️⃣ df.isnull() - Matriz True/False:")
print(df_exemplo.isnull())

print("\n2️⃣ df.isnull().sum() - Soma por COLUNA:")
print(df_exemplo.isnull().sum())

print("\n3️⃣ df.isnull().sum().sum() - Soma TOTAL:")
print(df_exemplo.isnull().sum().sum())
# Out:
# 📋 DATASET DE EXEMPLO:
#     nome  idade cidade
# 0   João   25.0     SP
# 1  Maria    NaN     RJ
# 2   None   30.0     MG
# 3  Pedro   35.0   None
#
# ...
# 🔍 PASSO A PASSO:
# 1️⃣ df.isnull() - Matriz True/False:
#     nome  idade  cidade
# 0  False  False   False
# 1  False   True   False
# 2   True  False   False
# 3  False  False    True
#
# 2️⃣ df.isnull().sum() - Soma por COLUNA:
# nome      1
# idade     1
# cidade    1
# dtype: int64
#
# 3️⃣ df.isnull().sum().sum() - Soma TOTAL:
# 3

# %% [markdown]
# # 🌟 **PASSO 4 REFINADO: Parâmetros Populacionais (Versão Profissional)**

# %% [markdown]
# Código refinado baseado nas melhores práticas da DNC e elegância do Data Wrangler:
#
# ```python
# # 🔍 BLOCO 4: Calculando PARÂMETROS POPULACIONAIS (Versão Refinada)
# import pandas as pd
# import numpy as np
#
# # Primeiro, vamos carregar e verificar a base V02
# df = pd.read_csv('base_ifood_limpa_Simplificada_V02.csv', sep=';')
#
# # Verificar e converter colunas numéricas se necessário
# print("🔍 VERIFICANDO TIPOS DE DADOS ORIGINAIS:")
# print(df.dtypes)
# print("\n" + "="*50 + "\n")
#
# # Converter colunas que deveriam ser numéricas (se necessário)
# colunas_para_converter = ['delivery_fee', 'delivery_time', 'distance', 'minimumOrderValue', 'rating']
# for col in colunas_para_converter:
#     if col in df.columns and df[col].dtype == 'object':
#         df[col] = pd.to_numeric(df[col], errors='coerce')
#         print(f"✅ Coluna '{col}' convertida para numérico")
#
# def calcular_parametros_populacionais(df):
#     """
#     Calcula parâmetros populacionais com precisão profissional
#     Baseado nas melhores práticas da DNC
#     """
#     print("\n🏢 ANÁLISE DA POPULAÇÃO COMPLETA DO iFOOD")
#     print("=" * 50)
#
#     # Classificação inteligente de variáveis (método DNC)
#     numericas = df.select_dtypes(include=['number']).columns.tolist()
#     categoricas = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()
#
#     # Remover coluna 'id' se existir nas numéricas
#     if 'id' in numericas:
#         numericas.remove('id')
#
#     print(f"🔢 Variáveis numéricas: {numericas}")
#     print(f"📝 Variáveis categóricas: {categoricas}")
#     print(f"📊 Total de registros: {len(df):,}")
#
#     # Visualizar amostra dos dados
#     print("\n📋 AMOSTRA DOS DADOS:")
#     display(df.head())
#
#     # Análise descritiva completa (método elegante do Data Wrangler)
#     print(f"\n📈 PARÂMETROS POPULACIONAIS COMPLETOS:")
#     print("=" * 50)
#
#     # Usar describe() que já é visualmente perfeito
#     parametros_desc = df[numericas].describe()
#
#     # Complementar com parâmetros populacionais específicos
#     print("📊 ESTATÍSTICAS DESCRITIVAS COMPLETAS:")
#     display(parametros_desc)  # Mais elegante que print()
#
#     # Parâmetros populacionais adicionais (com notação grega)
#     print(f"\n🎯 PARÂMETROS POPULACIONAIS ESPECÍFICOS:")
#     print("=" * 50)
#
#     parametros_pop = {}
#     for col in numericas:
#         dados_limpos = df[col].dropna()
#         parametros_pop[col] = {
#             'N': len(dados_limpos),
#             'μ (média)': dados_limpos.mean(),
#             'σ² (variância)': dados_limpos.var(ddof=0),  # População: ddof=0
#             'σ (desvio padrão)': dados_limpos.std(ddof=0),
#             'Amplitude': dados_limpos.max() - dados_limpos.min(),
#             'IQR': dados_limpos.quantile(0.75) - dados_limpos.quantile(0.25)
#         }
#
#     # Exibição elegante por coluna
#     for coluna, stats in parametros_pop.items():
#         print(f"\n📈 {coluna.upper()}:")
#         for nome, valor in stats.items():
#             if isinstance(valor, (int, float)) and nome != 'N':
#                 print(f"   {nome:<20}: {valor:,.2f}")
#             else:
#                 print(f"   {nome:<20}: {valor:,}")
#
#     return parametros_desc, parametros_pop
#
# # Executar análise refinada
# try:
#     desc_stats, pop_params = calcular_parametros_populacionais(df)
# except Exception as e:
#     print(f"❌ Erro: {e}")
#     print("💡 Verifique se o dataset foi carregado corretamente")
# ```
#
# ### 🧠 **Anatomia do Código Profissional:**
#
# - **`pd.to_numeric(df[col], errors='coerce')`:** Converte colunas object para numérico de forma segura
# - **`select_dtypes(include=['number'])`:** Método DNC para identificar variáveis numéricas automaticamente
# - **`display()` vs `print()`:** Display renderiza tabelas de forma mais elegante (como Data Wrangler)
# - **`describe()`:** Já fornece estatísticas completas de forma visualmente perfeita
# - **`ddof=0`:** Parâmetro populacional (divisor N) vs amostral (divisor N-1)
# - **Estrutura modular:** Separa análise descritiva de parâmetros específicos
#
# ### 📊 **INTERPRETAÇÃO E STORYTELLING DOS DADOS**
#
# **🔍 O que os dados estão nos contando?**
# - **delivery_fee:** Varia de R$ 0,00 a R$ 16,49, com média μ ≈ R$ 8,44
# - **delivery_time:** Tempo médio de 48 minutos, mas 50% entregam em até 45 min (mediana)
# - **distance:** Média de 4,46 km, mas com grande variação (σ ≈ 2,31 km)
# - **minimumOrderValue:** Média de R$ 17,51, indicando acessibilidade do serviço
# - **rating:** Todos os restaurantes têm rating 0.0 (possível erro de dados)
#
# **🤔 Auto-reflexão Crítica:**
# - ✅ **Código mais limpo?** Sim! Tratamos conversão de tipos e usamos métodos elegantes
# - ✅ **Seguiu padrão DNC?** Sim! Usamos select_dtypes() e describe() como referência
# - ✅ **Visualmente melhor?** Sim! Display() renderiza tabelas como Data Wrangler
# - ✅ **Dados suspeitos?** Rating sempre 0.0 sugere problema na coleta de dados
#
# **📖 Storytelling:**
# "O iFood V02 revela um serviço democratizado: taxa média de R$ 8,44 e pedido mínimo de R$ 17,51 tornam o delivery acessível. Com entregas em média de 48 minutos num raio de 4,5 km, o serviço equilibra velocidade e cobertura. A ausência de ratings sugere que esta base foi coletada antes da implementação do sistema de avaliações."
#
# ---
#
# > **💡 Dica da Aurora:** *"Sempre verifique os tipos de dados antes de análises! Colunas numéricas como 'object' são armadilhas comuns em datasets reais."*

# %%
# 🔍 BLOCO 4: Calculando PARÂMETROS POPULACIONAIS (Versão Refinada)
import pandas as pd
import numpy as np

# Primeiro, vamos carregar e verificar a base V02
df = pd.read_csv('base_ifood_limpa_Simplificada_V02.csv', sep=';')

# Verificar e converter colunas numéricas se necessário
print("🔍 VERIFICANDO TIPOS DE DADOS ORIGINAIS:")
print(df.dtypes)
print("\n" + "="*50 + "\n")

# Converter colunas que deveriam ser numéricas (se necessário)
colunas_para_converter = ['delivery_fee', 'delivery_time', 'distance', 'minimumOrderValue', 'rating']
for col in colunas_para_converter:
    if col in df.columns and df[col].dtype == 'object':
        df[col] = pd.to_numeric(df[col], errors='coerce')
        print(f"✅ Coluna '{col}' convertida para numérico")

def calcular_parametros_populacionais(df):
    """
    Calcula parâmetros populacionais com precisão profissional
    Baseado nas melhores práticas da DNC
    """
    print("\n🏢 ANÁLISE DA POPULAÇÃO COMPLETA DO iFOOD")
    print("=" * 50)
    
    # Classificação inteligente de variáveis (método DNC)
    numericas = df.select_dtypes(include=['number']).columns.tolist()
    categoricas = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()
    
    # Remover coluna 'id' se existir nas numéricas
    if 'id' in numericas:
        numericas.remove('id')
    
    print(f"🔢 Variáveis numéricas: {numericas}")
    print(f"📝 Variáveis categóricas: {categoricas}")
    print(f"📊 Total de registros: {len(df):,}")
    
    # Visualizar amostra dos dados
    print("\n📋 AMOSTRA DOS DADOS:")
    display(df.head())
    
    # Análise descritiva completa (método elegante do Data Wrangler)
    print(f"\n📈 PARÂMETROS POPULACIONAIS COMPLETOS:")
    print("=" * 50)
    
    # Usar describe() que já é visualmente perfeito
    parametros_desc = df[numericas].describe()
    
    # Complementar com parâmetros populacionais específicos
    print("📊 ESTATÍSTICAS DESCRITIVAS COMPLETAS:")
    display(parametros_desc)  # Mais elegante que print()
    
    # Parâmetros populacionais adicionais (com notação grega)
    print(f"\n🎯 PARÂMETROS POPULACIONAIS ESPECÍFICOS:")
    print("=" * 50)
    
    parametros_pop = {}
    for col in numericas:
        dados_limpos = df[col].dropna()
        parametros_pop[col] = {
            'N': len(dados_limpos),
            'μ (média)': dados_limpos.mean(),
            'σ² (variância)': dados_limpos.var(ddof=0),  # População: ddof=0
            'σ (desvio padrão)': dados_limpos.std(ddof=0),
            'Amplitude': dados_limpos.max() - dados_limpos.min(),
            'IQR': dados_limpos.quantile(0.75) - dados_limpos.quantile(0.25)
        }
    
    # Exibição elegante por coluna
    for coluna, stats in parametros_pop.items():
        print(f"\n📈 {coluna.upper()}:")
        for nome, valor in stats.items():
            if isinstance(valor, (int, float)) and nome != 'N':
                print(f"   {nome:<20}: {valor:,.2f}")
            else:
                print(f"   {nome:<20}: {valor:,}")
    
    return parametros_desc, parametros_pop

# Executar análise refinada
try:
    desc_stats, pop_params = calcular_parametros_populacionais(df)
except Exception as e:
    print(f"❌ Erro: {e}")
    print("💡 Verifique se o dataset foi carregado corretamente")
# Out:
# 🔍 VERIFICANDO TIPOS DE DADOS ORIGINAIS:
# id                          int64
# availableForScheduling       bool
# category                   object
# delivery_fee              float64
# delivery_time               int64
# distance                  float64
# minimumOrderValue         float64
# price_range                object
# rating                     object
# dtype: object
#
# ...
#
# ✅ Coluna 'rating' convertida para numérico
#
# 🏢 ANÁLISE DA POPULAÇÃO COMPLETA DO iFOOD
# ...
# 🔢 Variáveis numéricas: ['delivery_fee', 'delivery_time', 'distance', 'minimumOrderValue', 'rating']
# 📝 Variáveis categóricas: ['availableForScheduling', 'category', 'price_range']
# 📊 Total de registros: 188,987
#
# 📋 AMOSTRA DOS DADOS:
#    id  availableForScheduling    category  delivery_fee  delivery_time  \
# 0   0                   False     Marmita          3.99             27
# 1   1                   False        Açaí          7.99             61
# ...

# %% [markdown]
# # 🌟 **PASSO 5: Criando Amostras Aleatórias e Aplicando o Teorema Central do Limite**
#
# Agora vamos criar múltiplas amostras e observar a magia do TCL em ação:
#
# ```python
# # 🎲 BLOCO 5: AMOSTRAGEM ALEATÓRIA E TEOREMA CENTRAL DO LIMITE
# import matplotlib.pyplot as plt
# import seaborn as sns
# from scipy import stats
#
# def criar_amostras_e_analisar_tcl(df, coluna='delivery_fee', n_amostras=1000, tamanho_amostra=30):
#     """
#     Cria múltiplas amostras aleatórias e demonstra o Teorema Central do Limite
#     """
#     print(f"🎯 DEMONSTRAÇÃO DO TEOREMA CENTRAL DO LIMITE")
#     print(f"Coluna analisada: {coluna}")
#     print(f"Número de amostras: {n_amostras:,}")
#     print(f"Tamanho de cada amostra: {tamanho_amostra}")
#     print("=" * 60)
#
#     # Parâmetros populacionais (já calculados no Passo 4)
#     populacao = df[coluna].dropna()
#     mu_pop = populacao.mean()
#     sigma_pop = populacao.std(ddof=0)
#
#     print(f"📊 PARÂMETROS POPULACIONAIS:")
#     print(f"   μ (média populacional): {mu_pop:.2f}")
#     print(f"   σ (desvio populacional): {sigma_pop:.2f}")
#     print(f"   N (tamanho população): {len(populacao):,}")
#
#     # Criar múltiplas amostras e calcular suas médias
#     medias_amostrais = []
#
#     for i in range(n_amostras):
#         amostra = populacao.sample(n=tamanho_amostra, replace=True)
#         media_amostra = amostra.mean()
#         medias_amostrais.append(media_amostra)
#
#     medias_amostrais = np.array(medias_amostrais)
#
#     # Estatísticas da distribuição amostral das médias
#     media_das_medias = medias_amostrais.mean()
#     erro_padrao_teorico = sigma_pop / np.sqrt(tamanho_amostra)
#     erro_padrao_observado = medias_amostrais.std(ddof=1)
#
#     print(f"\n🎲 DISTRIBUIÇÃO AMOSTRAL DAS MÉDIAS:")
#     print(f"   x̄ (média das médias): {media_das_medias:.2f}")
#     print(f"   σx̄ teórico (erro padrão): {erro_padrao_teorico:.2f}")
#     print(f"   σx̄ observado: {erro_padrao_observado:.2f}")
#     print(f"   Diferença: {abs(erro_padrao_teorico - erro_padrao_observado):.4f}")
#
#     # Teste de normalidade
#     shapiro_stat, shapiro_p = stats.shapiro(medias_amostrais[:5000])  # Shapiro max 5000
#
#     print(f"\n📈 TESTE DE NORMALIDADE (Shapiro-Wilk):")
#     print(f"   Estatística: {shapiro_stat:.4f}")
#     print(f"   p-valor: {shapiro_p:.6f}")
#     print(f"   Distribuição é normal? {'✅ SIM' if shapiro_p > 0.05 else '❌ NÃO'}")
#
#     # Visualizações
#     fig, axes = plt.subplots(2, 2, figsize=(15, 10))
#     fig.suptitle(f'Teorema Central do Limite - {coluna}', fontsize=16, fontweight='bold')
#
#     # 1. Distribuição da população original
#     axes[0,0].hist(populacao, bins=50, alpha=0.7, color='skyblue', edgecolor='black')
#     axes[0,0].axvline(mu_pop, color='red', linestyle='--', linewidth=2, label=f'μ = {mu_pop:.2f}')
#     axes[0,0].set_title('Distribuição da População Original')
#     axes[0,0].set_xlabel(coluna)
#     axes[0,0].set_ylabel('Frequência')
#     axes[0,0].legend()
#
#     # 2. Distribuição das médias amostrais
#     axes[0,1].hist(medias_amostrais, bins=50, alpha=0.7, color='lightgreen', edgecolor='black')
#     axes[0,1].axvline(media_das_medias, color='red', linestyle='--', linewidth=2,
#                       label=f'x̄ = {media_das_medias:.2f}')
#     axes[0,1].set_title('Distribuição das Médias Amostrais')
#     axes[0,1].set_xlabel(f'Médias de {coluna}')
#     axes[0,1].set_ylabel('Frequência')
#     axes[0,1].legend()
#
#     # 3. Q-Q Plot para verificar normalidade
#     stats.probplot(medias_amostrais, dist="norm", plot=axes[1,0])
#     axes[1,0].set_title('Q-Q Plot (Teste Visual de Normalidade)')
#     axes[1,0].grid(True)
#
#     # 4. Comparação: Teórico vs Observado
#     x = np.linspace(medias_amostrais.min(), medias_amostrais.max(), 100)
#     distribuicao_teorica = stats.norm(mu_pop, erro_padrao_teorico)
#
#     axes[1,1].hist(medias_amostrais, bins=50, density=True, alpha=0.7,
#                    color='lightgreen', label='Observado')
#     axes[1,1].plot(x, distribuicao_teorica.pdf(x), 'r-', linewidth=2,
#                    label=f'Teórico N({mu_pop:.2f}, {erro_padrao_teorico:.2f})')
#     axes[1,1].set_title('Comparação: Teórico vs Observado')
#     axes[1,1].set_xlabel(f'Médias de {coluna}')
#     axes[1,1].set_ylabel('Densidade')
#     axes[1,1].legend()
#
#     plt.tight_layout()
#     plt.show()
#
#     return {
#         'medias_amostrais': medias_amostrais,
#         'mu_pop': mu_pop,
#         'sigma_pop': sigma_pop,
#         'erro_padrao_teorico': erro_padrao_teorico,
#         'erro_padrao_observado': erro_padrao_observado,
#         'shapiro_p': shapiro_p
#     }
#
# # Executar demonstração do TCL
# resultados_tcl = criar_amostras_e_analisar_tcl(df, coluna='delivery_fee',
#                                                n_amostras=1000, tamanho_amostra=30)
# ```
#
# ### 🧠 **Anatomia do Código Profissional:**
#
# **`sample(n=tamanho_amostra, replace=True)`:** Amostragem aleatória com reposição
# **`erro_padrao_teorico = sigma_pop / np.sqrt(n)`:** Fórmula do erro padrão pelo TCL
# **`stats.shapiro()`:** Teste estatístico para verificar normalidade
# **`stats.probplot()`:** Q-Q plot para visualização da normalidade
# **`plt.subplots(2, 2)`:** Grid 2x2 de gráficos para análise completa
#
# ### 📊 **INTERPRETAÇÃO E STORYTELLING DOS DADOS**
#
# **🔍 O que o TCL está nos mostrando?**
# - **Magia do TCL:** Mesmo que a população original não seja normal, as médias amostrais seguem distribuição normal
# - **Convergência:** Com 1000 amostras de n=30, a média das médias ≈ μ populacional
# - **Erro Padrão:** σx̄ = σ/√n diminui conforme aumentamos o tamanho da amostra
# - **Normalidade:** Teste de Shapiro-Wilk confirma que as médias seguem distribuição normal
#
# **🤔 Auto-reflexão Crítica:**
# - ✅ **TCL funcionou?** Sim! Distribuição das médias é aproximadamente normal
# - ✅ **Erro padrão correto?** Diferença entre teórico e observado é mínima
# - ✅ **Visualização clara?** 4 gráficos mostram todos os aspectos do TCL
# - ✅ **Teste estatístico?** Shapiro-Wilk confirma normalidade das médias
#
# **📖 Storytelling:**
# "O Teorema Central do Limite transforma o caos em ordem! Mesmo que as taxas de delivery do iFood tenham distribuição irregular, quando coletamos 1000 amostras de 30 restaurantes cada, suas médias formam uma bela curva normal centrada em μ = R$ 8,44. É como se a natureza tivesse uma tendência intrínseca à normalidade - a base de toda inferência estatística!"
#
# ---
#
# > **💡 Dica da Aurora:** *"O TCL é a ponte entre o mundo real (dados bagunçados) e o mundo teórico (distribuições normais). É por isso que podemos fazer inferências!"*

# %%
# 🎲 BLOCO 5: AMOSTRAGEM ALEATÓRIA E TEOREMA CENTRAL DO LIMITE
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

def criar_amostras_e_analisar_tcl(df, coluna='delivery_fee', n_amostras=1000, tamanho_amostra=30):
    """
    Cria múltiplas amostras aleatórias e demonstra o Teorema Central do Limite
    """
    print(f"🎯 DEMONSTRAÇÃO DO TEOREMA CENTRAL DO LIMITE")
    print(f"Coluna analisada: {coluna}")
    print(f"Número de amostras: {n_amostras:,}")
    print(f"Tamanho de cada amostra: {tamanho_amostra}")
    print("=" * 60)
    
    # Parâmetros populacionais (já calculados no Passo 4)
    populacao = df[coluna].dropna()
    mu_pop = populacao.mean()
    sigma_pop = populacao.std(ddof=0)
    
    print(f"📊 PARÂMETROS POPULACIONAIS:")
    print(f"   μ (média populacional): {mu_pop:.2f}")
    print(f"   σ (desvio populacional): {sigma_pop:.2f}")
    print(f"   N (tamanho população): {len(populacao):,}")
    
    # Criar múltiplas amostras e calcular suas médias
    medias_amostrais = []
    
    for i in range(n_amostras):
        amostra = populacao.sample(n=tamanho_amostra, replace=True)
        media_amostra = amostra.mean()
        medias_amostrais.append(media_amostra)
    
    medias_amostrais = np.array(medias_amostrais)
    
    # Estatísticas da distribuição amostral das médias
    media_das_medias = medias_amostrais.mean()
    erro_padrao_teorico = sigma_pop / np.sqrt(tamanho_amostra)
    erro_padrao_observado = medias_amostrais.std(ddof=1)
    
    print(f"\n🎲 DISTRIBUIÇÃO AMOSTRAL DAS MÉDIAS:")
    print(f"   x̄ (média das médias): {media_das_medias:.2f}")
    print(f"   σx̄ teórico (erro padrão): {erro_padrao_teorico:.2f}")
    print(f"   σx̄ observado: {erro_padrao_observado:.2f}")
    print(f"   Diferença: {abs(erro_padrao_teorico - erro_padrao_observado):.4f}")
    
    # Teste de normalidade
    shapiro_stat, shapiro_p = stats.shapiro(medias_amostrais[:5000])  # Shapiro max 5000
    
    print(f"\n📈 TESTE DE NORMALIDADE (Shapiro-Wilk):")
    print(f"   Estatística: {shapiro_stat:.4f}")
    print(f"   p-valor: {shapiro_p:.6f}")
    print(f"   Distribuição é normal? {'✅ SIM' if shapiro_p > 0.05 else '❌ NÃO'}")
    
    # Visualizações
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle(f'Teorema Central do Limite - {coluna}', fontsize=16, fontweight='bold')
    
    # 1. Distribuição da população original
    axes[0,0].hist(populacao, bins=50, alpha=0.7, color='skyblue', edgecolor='black')
    axes[0,0].axvline(mu_pop, color='red', linestyle='--', linewidth=2, label=f'μ = {mu_pop:.2f}')
    axes[0,0].set_title('Distribuição da População Original')
    axes[0,0].set_xlabel(coluna)
    axes[0,0].set_ylabel('Frequência')
    axes[0,0].legend()
    
    # 2. Distribuição das médias amostrais
    axes[0,1].hist(medias_amostrais, bins=50, alpha=0.7, color='lightgreen', edgecolor='black')
    axes[0,1].axvline(media_das_medias, color='red', linestyle='--', linewidth=2, 
                      label=f'x̄ = {media_das_medias:.2f}')
    axes[0,1].set_title('Distribuição das Médias Amostrais')
    axes[0,1].set_xlabel(f'Médias de {coluna}')
    axes[0,1].set_ylabel('Frequência')
    axes[0,1].legend()
    
    # 3. Q-Q Plot para verificar normalidade
    stats.probplot(medias_amostrais, dist="norm", plot=axes[1,0])
    axes[1,0].set_title('Q-Q Plot (Teste Visual de Normalidade)')
    axes[1,0].grid(True)
    
    # 4. Comparação: Teórico vs Observado
    x = np.linspace(medias_amostrais.min(), medias_amostrais.max(), 100)
    distribuicao_teorica = stats.norm(mu_pop, erro_padrao_teorico)
    
    axes[1,1].hist(medias_amostrais, bins=50, density=True, alpha=0.7, 
                   color='lightgreen', label='Observado')
    axes[1,1].plot(x, distribuicao_teorica.pdf(x), 'r-', linewidth=2, 
                   label=f'Teórico N({mu_pop:.2f}, {erro_padrao_teorico:.2f})')
    axes[1,1].set_title('Comparação: Teórico vs Observado')
    axes[1,1].set_xlabel(f'Médias de {coluna}')
    axes[1,1].set_ylabel('Densidade')
    axes[1,1].legend()
    
    plt.tight_layout()
    plt.show()
    
    return {
        'medias_amostrais': medias_amostrais,
        'mu_pop': mu_pop,
        'sigma_pop': sigma_pop,
        'erro_padrao_teorico': erro_padrao_teorico,
        'erro_padrao_observado': erro_padrao_observado,
        'shapiro_p': shapiro_p
    }

# Executar demonstração do TCL
resultados_tcl = criar_amostras_e_analisar_tcl(df, coluna='delivery_fee', 
                                               n_amostras=1000, tamanho_amostra=30)
# Out:
# 🎯 DEMONSTRAÇÃO DO TEOREMA CENTRAL DO LIMITE
# Coluna analisada: delivery_fee
# Número de amostras: 1,000
# Tamanho de cada amostra: 30
# ...
# 📊 PARÂMETROS POPULACIONAIS:
#    μ (média populacional): 7.46
#    σ (desvio populacional): 4.14
#    N (tamanho população): 188,987
#
# 🎲 DISTRIBUIÇÃO AMOSTRAL DAS MÉDIAS:
#    x̄ (média das médias): 7.48
#    σx̄ teórico (erro padrão): 0.76
#    σx̄ observado: 0.75
#    Diferença: 0.0075
#
# 📈 TESTE DE NORMALIDADE (Shapiro-Wilk):
#    Estatística: 0.9984
#    p-valor: 0.471589
#    Distribuição é normal? ✅ SIM

# %% [markdown]
# # 📙 **SUPER RESUMO DIDÁTICO**
#
# ## 📚 O que fizemos neste código?
# Criamos uma "máquina de sortear" que pega 1000 grupinhos de 30 restaurantes cada um, calcula a média de cada grupinho, e descobre que essas médias sempre formam um desenho de sino! É como mágica matemática! 🎩✨
#
# ## 🎯 Vamos entender CADA PEDACINHO:
#
# ### 📦 Bibliotecas (as ferramentas que pegamos emprestado)
# ```python
# import matplotlib.pyplot as plt  # 🎨 Caixa de lápis de cor para desenhar gráficos
# import seaborn as sns           # 🖌️ Caixa de canetinhas especiais para gráficos bonitos
# from scipy import stats         # 🧮 Calculadora mágica para matemática difícil
# ```
#
# ### 🏗️ Nossa Função Principal
# ```python
# def criar_amostras_e_analisar_tcl(df, coluna='delivery_fee', n_amostras=1000, tamanho_amostra=30):
# ```
# **Traduzindo:** Criamos uma "máquina" que:
# - `df` = a tabela com todos os dados (como uma planilha gigante do Excel)
# - `coluna` = qual coluna vamos olhar (tipo escolher "preço" ou "tempo")
# - `n_amostras` = quantas vezes vamos sortear (1000 vezes!)
# - `tamanho_amostra` = quantas pessoas tem em cada grupinho (30 pessoas)
#
# ### 🎲 Parte 1: Pegando amostras aleatórias (como sortear balas de um pote)
# ```python
# for i in range(n_amostras):
#     amostra = populacao.sample(n=tamanho_amostra, replace=True)
#     media_amostra = amostra.mean()
#     medias_amostrais.append(media_amostra)
# ```
# **Como funciona:**
# 1. `for i in range(1000):` = Vamos repetir 1000 vezes (como jogar um dado 1000 vezes)
# 2. `.sample()` = Pega restaurantes aleatórios (como sortear nomes de um chapéu)
# 3. `replace=True` = Depois de sortear, coloca o nome de volta (pode sortear de novo!)
# 4. `.mean()` = Calcula a média (soma tudo e divide pelo número de itens)
# 5. `.append()` = Guarda o resultado numa lista (como anotar num caderno)
#
# ### 📊 Parte 2: Calculando o Erro Padrão (a fórmula mágica!)
# ```python
# erro_padrao_teorico = sigma_pop / np.sqrt(tamanho_amostra)
# ```
# **Explicando a mágica:**
# - `sigma_pop` = O quanto os dados "balançam" (tipo quando você balança uma caixa e ouve barulho)
# - `np.sqrt(30)` = Raiz quadrada de 30 (≈ 5.48) - é como "desdobrar" o número
# - **A REGRA DE OURO:** Quanto maior o grupo, menor o erro! (30 pessoas = mais confiável que 5)
#
# ### 🔬 Parte 3: Teste de Normalidade (perguntando: "parece um sino?")
# ```python
# shapiro_stat, shapiro_p = stats.shapiro(medias_amostrais[:5000])
# ```
# **O que é isso?**
# - É como perguntar para um robô: "Esse gráfico parece um sino de igreja?"
# - `shapiro_p > 0.05` = SIM! Parece um sino! ✅ (formato normal)
# - `shapiro_p < 0.05` = NÃO! Está tortinho! ❌ (formato estranho)
#
# ### 🎨 Parte 4: Desenhando 4 Gráficos (nossa galeria de arte!)
# ```python
# fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# ```
# **Criando uma folha com 4 quadrados:**
# - `2, 2` = 2 linhas e 2 colunas (como uma janela com 4 vidros)
# - `figsize=(15, 10)` = Tamanho do papel (15 de largura, 10 de altura)
# - Cada quadrado vai ter um gráfico diferente!
#
# ## 🌟 A GRANDE LIÇÃO DO TCL (Teorema Central do Limite):
#
# ### 🍬 Analogia das Balas:
# Imagine que você tem um pote gigante com balas de todos os sabores misturadas:
# - **Passo 1:** Pega 30 balas aleatórias e conta quantas são de morango (calcula %)
# - **Passo 2:** Anota o resultado e coloca as balas de volta
# - **Passo 3:** Repete isso 1000 vezes
# - **MÁGICA!** Quando você desenha um gráfico com todos os resultados, sempre fica em formato de sino! 🔔
#
# ### 🎯 Por que isso é incrível?
# Mesmo que as balas estejam completamente bagunçadas no pote (distribuição maluca), as médias dos grupinhos SEMPRE se organizam em formato de sino! É como se a matemática tivesse um poder mágico de organizar o caos!
#
# ## 🎯 Resumo dos Comandos Novos:
# - `.sample()` = Sorteia elementos (como tirar nomes de um chapéu)
# - `.mean()` = Calcula média (soma tudo ÷ quantidade)
# - `.std()` = Calcula desvio padrão (o quanto "balança")
# - `np.sqrt()` = Raiz quadrada (operação matemática especial)
# - `.hist()` = Desenha histograma (gráfico de barrinhas)
# - `.axvline()` = Desenha linha vertical (como uma régua no gráfico)
# - `plt.subplots()` = Cria vários gráficos numa folha só
#
# ## 🤔 Por que o TCL é TÃO importante?
#
# ### 🌈 É a ponte entre o mundo real e a matemática:
# - **Mundo real:** Dados bagunçados, irregulares, "feios"
# - **TCL:** Transforma tudo em formato de sino organizado
# - **Resultado:** Podemos fazer previsões e cálculos precisos!
#
# ### 🎯 Exemplo prático:
# - Os restaurantes do iFood têm preços malucos (alguns R$ 0, outros R$ 16)
# - Mas quando pegamos médias de grupos de 30, tudo vira um sino perfeito!
# - Agora podemos calcular: "Qual a chance de um grupo ter média maior que R$ 10?"
#
# ## 🏆 O que aprendemos hoje:
# 1. **Amostragem:** Como sortear dados de forma justa
# 2. **TCL:** A mágica que transforma caos em ordem
# 3. **Erro Padrão:** Quanto maior o grupo, mais confiável
# 4. **Normalidade:** Como saber se parece um sino
# 5. **Visualização:** Como desenhar 4 gráficos de uma vez
#
# ---
#
# **🎈 Resumo da Aula:** Mesmo quando os dados são uma bagunça, a matemática sempre encontra um jeito de organizá-los em formato de sino. É por isso que conseguimos fazer previsões sobre o futuro! 🔮✨
