# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercício 1 – Classificação de Dados
#
# <br>
#
# Dado o conjunto de variáveis abaixo, classifique-as como quantitativa discreta, quantitativa contínua ou qualitativa:
#
# Número de clientes
#
# <br>
#
# 1. Número de clientes atendidos por dia.
#
# 2. Temperatura ambiente medida em graus Celsius.
#
# 3. Grau de satisfação de um cliente (ruim, bom, excelente).
#
# 4. Peso de produtos em um armazém.
#
# 5. Tipos de formas de pagamento (dinheiro, cartão, Pix).

# %%
'''

1. Quantititativa Discreta;

2. Quantitativa Contínua;

3. Qualitativa Ordinal;

4. Quantitativa Contínua;

5. Qualitativa Nominal;

'''

# %% [markdown]
# ---
# ### Exercício 2 - Estatísticas Descritivas de Dados Quantitativos
#
# <br>
#
# Um pesquisador coletou as seguintes alturas (em cm) de um grupo de pessoas:
#
# ```Python
# alturas = [160, 170, 165, 180, 175, 172, 168, 168, 169, 174, 176]
# ```
#
# <br>
#
# 📌 Passos:
#
# 1. Calcule a média, mediana e desvio padrão dessas
# alturas.
#
# 2. O conjunto de dados tem distribuição simétrica ou
# assimétrica?

# %%
alturas = [160, 170, 165, 180, 175, 172, 168, 168, 169, 174, 176]

# %%
## 1. Calcule a média, mediana e desvio padrão dessas alturas.

media = np.mean(alturas)
mediana = np.median(alturas)
devio_padra = np.std(alturas)

print(f"Média: {media:.2f}")
print(f"Mediana: {mediana}")
print(f"Desvio Padrão: {devio_padra:.2f}")
# Out:
# Média: 170.64
# Mediana: 170.0
# Desvio Padrão: 5.31

# %%
## 2. O conjunto de dados tem distribuição simétrica ou assimétrica?

'''
Distribuição simétrica

'''

# %% [markdown]
# ---
# ### Exercício 3 - Análise de Frequência para Dados Qualitativos
#
# <br>
# Uma empresa coletou feedbacks de clientes sobre um novo produto. Os resultados  foram:
#
# <br>
#
# ```Python
# feedbacks = ["Bom", "Ruim", "Excelente", "Bom", "Regular", "Bom", "Excelente", "Ruim", "Bom", "Regular"]
# ```
#
# <br>
#
# 📌 Passos:
# 1. Construa uma tabela de frequência para os feedbacks.
# 2. Qual é a categoria mais frequente?
# 3. Represente os dados em um gráfico de barras.

# %%
feedbacks = ["Bom", "Ruim", "Excelente", "Bom", "Regular", "Bom", "Excelente", "Ruim", "Bom", "Regular"]

# %%
df = pd.DataFrame(feedbacks, columns=['feedbacks'])
df
# Out:
#    feedbacks
# 0        Bom
# 1       Ruim
# 2  Excelente
# 3        Bom
# 4    Regular
# 5        Bom
# 6  Excelente
# 7       Ruim
# 8        Bom
# 9    Regular

# %%
## 1. Construa uma tabela de frequência para os feedbacks.
tabela = df.groupby('feedbacks').size().reset_index(name='counts')
tabela
# Out:
#    feedbacks  counts
# 0        Bom       4
# 1  Excelente       2
# 2    Regular       2
# 3       Ruim       2

# %%
## 2. Qual é a categoria mais frequente?

'''
Bom.
'''

# %%
## 3. Represente os dados em um gráfico de barras.

plt.figure(figsize=(10, 6))
plot = sns.barplot(x='feedbacks', y='counts',  data=tabela)
for i in plot.patches:
    plot.annotate(f'{i.get_height()}', (i.get_x() + i.get_width() / 2, i.get_height()), ha='center', va='center', size=10, xytext=(0, 5), textcoords='offset points')
plt.xlabel('Feedbacks')
plt.ylabel('Frequência')
plt.title('Tabela de Frequência dos Feedbacks')
plt.show()

# %% [markdown]
# ---
# ### Exercício 4 – Comparação entre Análise Quantitativa e Qualitativa
#
# <br>
#
# Um estudo avaliou a relação entre nível de escolaridade e salário mensal de um grupo de trabalhadores:
#
# <br>
#
# | Nível de Escolaridade | Salário Médio (R$) |
# |---|---|
# | Ensino Médio | 2.500 |
# | Graduação | 5.500 |
# | Pós-graduação | 8.000 |
#
# <br>
#
# 📌 Perguntas:
#
# 1. A variável "Nível de Escolaridade" é quantitativa ou
# qualitativa?
#
# 2. O que o salário médio representa na análise
# quantitativa?
#
# 3. Como esses dados poderiam ser analisados
# qualitativamente?

# %%
## 1. A variável "Nível de Escolaridade" é quantitativa ou qualitativa?

'''
Qualitativa Ordinal.
'''

# %%
## 2. O que o salário médio representa na análise quantitativa?

'''
Representa um indicador quantitativo, usado para comparar grupos.
'''

# %%
## 3. Como esses dados poderiam ser analisados qualitativamente?

'''
Análise qualitativa: Poderia envolver entrevistas para entender como o nível de escolaridade impacta oportunidades no mercado.
'''

# %% [markdown]
# ---
# ## 5. Comparação entre Análise Quantitativa e Qualitativa
#
# <br>
#
# Um analista de dados quer verificar a relação entre o número de horas de estudo e a nota final em um exame.
#
# <br>
#
# ```
# horas_estudo = [2, 4, 6, 8, 10, 12, 14]
#
# notas = [50, 55, 65, 70, 80, 85, 90]
#
# ```
#
# <br>
#
# 📌 Passos:
# 1. Calcule a correlação entre horas de estudo e nota final.
# 2. A relação entre essas variáveis é positiva 2. ou negativa?
# 3. Qual conclusão pode ser tirada a partir desse resultado?

# %%
horas_estudo = [2, 4, 6, 8, 10, 12, 14]
notas = [50, 55, 65, 70, 80, 85, 90]

# %%
## 1. Calcule a correlação entre horas de estudo e nota final.

correlation = np.corrcoef(horas_estudo, notas)[0, 1]
print(f"Correlação: {correlation}")
# Out:
# Correlação: 0.9951052080056662

# %%
## 2. A relação entre essas variáveis é positiva 2. ou negativa?

'''
Positiva forte
'''

# %%
## 3. Qual conclusão pode ser tirada a partir desse resultado?

'''
Existe uma relação direta, indicando que estudar mais melhora o desempenho no exame.
'''
