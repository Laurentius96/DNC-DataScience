# %% [markdown]
# # Step 1: Business Understanding
#
# Um e-commerce do Reino Unido contratou os alunos da DNC para agruparem seus clientes com base nas métricas RFM (discutidas abaixo), para então definir estratégias de fidelização.
#
# RFM:
# - R (Recency): Tempo que o cliente realizou a última compra (em dias)
# - F (Frequency): Quantidade de compras realizadas pelo cliente
# - M (Monetary): Valor do **ticket médio** gasto pelo cliente
#
#
# O conjunto de dados fornecido contém transações ocorridas entre dezembro de 2010 e dezembro de 2011.
#
# Seu objetivo é clusterizar os clientes com base em suas métricas de RFM.
#
# Fonte do dataset [neste link](https://www.kaggle.com/datasets/carrie1/ecommerce-data).

# %% [markdown]
# # Step 2 : Data Understanding

# %% [markdown]
# ## Setup

# %%
# %%capture
# %pip install sidetable

# %%
import numpy as np
import pandas as pd
import sidetable

import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans, DBSCAN, MeanShift, AgglomerativeClustering
from sklearn.preprocessing import StandardScaler, scale

from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

from yellowbrick.cluster import kelbow_visualizer

# %%
# https://matplotlib.org/stable/tutorials/introductory/customizing.html
sns.set_theme(
    context='talk',
    style='ticks',
    font_scale=.8,
    palette='tab10',
    rc={
        'figure.figsize': (12,8),
        'axes.grid': True,
        'grid.alpha': .2,
        'axes.titlesize': 'x-large',
        'axes.titleweight': 'bold',
        'axes.titlepad': 20,
    }
)

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/cmcouto-silva/datasets/main/datasets/e-commerce.csv', encoding='latin1')
print(df.shape)
df.head()
# Out:
# (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## Data understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.InvoiceNo.sort_values()
# Out:
# 0          536365
# 1          536365
# 2          536365
# 3          536365
# 4          536365
#            ...
# 540449    C581490
# 541541    C581499
# 541715    C581568
# 541716    C581569
# 541717    C581569
# Name: InvoiceNo, Length: 541909, dtype: object

# %%
df[['Description','Country']].nunique()
# Out:
# Description    4223
# Country          38
# dtype: int64

# %%
df['Country'].value_counts(normalize=True, ascending=True).plot.barh(figsize=(12,10))
# Out:
# <Axes: ylabel='Country'>

# %%
df[['Quantity','UnitPrice']].describe()
# Out:
#             Quantity      UnitPrice
# count  541909.000000  541909.000000
# mean        9.552250       4.611114
# std       218.081158      96.759853
# min    -80995.000000  -11062.060000
# 25%         1.000000       1.250000
# 50%         3.000000       2.080000
# 75%        10.000000       4.130000
# max     80995.000000   38970.000000

# %%
df.stb.freq(['Country'])
# Out:
#                  Country   count    percent  cumulative_count  \
# 0         United Kingdom  495478  91.431956            495478
# 1                Germany    9495   1.752139            504973
# 2                 France    8557   1.579047            513530
# 3                   EIRE    8196   1.512431            521726
# 4                  Spain    2533   0.467422            524259
# 5            Netherlands    2371   0.437527            526630
# 6                Belgium    2069   0.381798            528699
# 7            Switzerland    2002   0.369435            530701
# 8               Portugal    1519   0.280305            532220
# 9              Australia    1259   0.232327            533479
# 10                Norway    1086   0.200403            534565
# 11                 Italy     803   0.148180            535368
# 12       Channel Islands     758   0.139876            536126
# 13               Finland     695   0.128250            536821
# 14                Cyprus     622   0.114779            537443
# 15                Sweden     462   0.085254            537905
# 16           Unspecified     446   0.082302            538351
# 17               Austria     401   0.073998            538752
# 18               Denmark     389   0.071783            539141
# 19                 Japan     358   0.066063            539499
# 20                Poland     341   0.062926            539840
# 21                Israel     297   0.054806            540137
# 22                   USA     291   0.053699            540428
# 23             Hong Kong     288   0.053145            540716
# 24             Singapore     229   0.042258            540945
# 25               Iceland     182   0.033585            541127
# 26                Canada     151   0.027864            541278
# 27                Greece     146   0.026942            541424
# 28                 Malta     127   0.023436            541551
# 29  United Arab Emirates      68   0.012548            541619
# 30    European Community      61   0.011257            541680
# 31                   RSA      58   0.010703            541738
# 32               Lebanon      45   0.008304            541783
# 33             Lithuania      35   0.006459            541818
# 34                Brazil      32   0.005905            541850
# 35        Czech Republic      30   0.005536            541880
# 36               Bahrain      19   0.003506            541899
# 37          Saudi Arabia      10   0.001845            541909
#
#     cumulative_percent
# 0            91.431956
# 1            93.184095
# 2            94.763143
# 3            96.275574
# 4            96.742996
# 5            97.180523
# 6            97.562321
# 7            97.931756
# 8            98.212061
# 9            98.444388
# 10           98.644791
# 11           98.792971
# 12           98.932847
# 13           99.061097
# 14           99.175876
# 15           99.261131
# 16           99.343432
# 17           99.417430
# 18           99.489213
# 19           99.555276
# 20           99.618202
# 21           99.673008
# 22           99.726707
# 23           99.779852
# 24           99.822110
# 25           99.855695
# 26           99.883560
# 27           99.910502
# 28           99.933937
# 29           99.946485
# 30           99.957742
# 31           99.968445
# 32           99.976749
# 33           99.983208
# 34           99.989113
# 35           99.994649
# 36           99.998155
# 37          100.000000

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# CustomerID     135080
# Description      1454
# StockCode           0
# InvoiceNo           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(5268)

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country  price_total
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 5 2010-12-01 08:26:00       7.65       17850  United Kingdom        15.30
# 6 2010-12-01 08:26:00       4.25       17850  United Kingdom        25.50
# 7 2010-12-01 08:28:00       1.85       17850  United Kingdom        11.10
# 8 2010-12-01 08:28:00       1.85       17850  United Kingdom        11.10
# 9 2010-12-01 08:34:00       1.69       13047  United Kingdom        54.08

# %% [markdown]
# # Step 3 : Data Preparation

# %% [markdown]
# ## Data Cleaning

# %%
df.stb.missing()
# Out:
#              missing   total    percent
# CustomerID    135080  541909  24.926694
# Description     1454  541909   0.268311
# StockCode          0  541909   0.000000
# InvoiceNo          0  541909   0.000000
# Quantity           0  541909   0.000000
# InvoiceDate        0  541909   0.000000
# UnitPrice          0  541909   0.000000
# Country            0  541909   0.000000

# %%
df = df.dropna(subset=['CustomerID'])

# %%
df.stb.missing()
# Out:
#              missing   total  percent
# InvoiceNo          0  406829      0.0
# StockCode          0  406829      0.0
# Description        0  406829      0.0
# Quantity           0  406829      0.0
# InvoiceDate        0  406829      0.0
# UnitPrice          0  406829      0.0
# CustomerID         0  406829      0.0
# Country            0  406829      0.0

# %%
# %%timeit
pd.to_datetime(df.InvoiceDate)
# Out:
# 77.7 ms ± 2.66 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
pd.to_datetime(df.InvoiceDate, format='%m/%d/%Y %H:%M')
# Out:
# 77.8 ms ± 4.93 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df['InvoiceDate'] = pd.to_datetime(df.InvoiceDate, format='%m/%d/%Y %H:%M')
# Out:
# C:\Users\bianc\AppData\Local\Temp\ipykernel_50052\1106622787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['InvoiceDate'] = pd.to_datetime(df.InvoiceDate, format='%m/%d/%Y %H:%M')

# %%
df['CustomerID'] = df['CustomerID'].astype(int)
df['Country'] = df['Country'].astype('category')
# Out:
# C:\Users\bianc\AppData\Local\Temp\ipykernel_50052\1154679171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CustomerID'] = df['CustomerID'].astype(int)
# C:\Users\bianc\AppData\Local\Temp\ipykernel_50052\1154679171.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country'] = df['Country'].astype('category')

# %%
df = df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  int64
#  7   Country      406829 non-null  category
# dtypes: category(1), datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 25.2+ MB

# %%
df.InvoiceDate.agg(['min','max'])
# Out:
# min   2010-12-01 08:26:00
# max   2011-12-09 12:50:00
# Name: InvoiceDate, dtype: datetime64[ns]

# %%
below0 = df[['Quantity','UnitPrice']].le(0).any(axis=1)
df = df[~below0].copy()

# %%
df[['Quantity','UnitPrice']].plot.box()
# Out:
# <Axes: >

# %%
df.query('Quantity>10_000')
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61619     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 540421    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 61619  2011-01-18 10:01:00       1.04       12346  United Kingdom
# 540421 2011-12-09 09:15:00       2.08       16446  United Kingdom

# %%
df.query('Quantity<10_000')[['Quantity','UnitPrice']].plot.box()
# Out:
# <Axes: >

# %%
df.query('UnitPrice>8_000')
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 173382    551697      POST     POSTAGE         1 2011-05-03 13:46:00
#
#         UnitPrice  CustomerID         Country
# 173382    8142.75       16029  United Kingdom

# %%
df = df.query('Quantity<10_000 & UnitPrice<8_000').copy()

# %%
df['price_total'] = df.Quantity * df.UnitPrice
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  price_total
# 0      2010-12-01 08:26:00       2.55       17850  United Kingdom        15.30
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 2      2010-12-01 08:26:00       2.75       17850  United Kingdom        22.00
# 3      2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 4      2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# ...                    ...        ...         ...             ...          ...
# 541904 2011-12-09 12:50:00       0.85       12680          France        10.20
# 541905 2011-12-09 12:50:00       2.10       12680          France        12.60
# 541906 2011-12-09 12:50:00       4.15       12680          France        16.60
# 541907 2011-12-09 12:50:00       4.15       12680          France        16.60
# 541908 2011-12-09 12:50:00       4.95       12680          France        14.85
#
# [397881 rows x 9 columns]

# %% [markdown]
# RFM

# %%
pd.Timestamp.today()
# Out:
# Timestamp('2026-02-20 15:28:53.238193')

# %%
pd.Timestamp('2012-01-01')
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
df_rfm = (
  df.groupby('CustomerID')
  .agg(
      R = ('InvoiceDate', lambda x: (pd.Timestamp('2012-01-01') - x.max()).days),
      F = ('InvoiceNo', 'nunique'),
      M = ('price_total', 'mean')
  )
)

df_rfm
# Out:
#               R   F          M
# CustomerID
# 12347        24   7  23.681319
# 12348        97   4  57.975484
# 12349        40   1  24.076027
# 12350       332   1  19.670588
# 12352        58   8  29.482824
# ...         ...  ..        ...
# 18280       299   1  18.060000
# 18281       202   1  11.545714
# 18282        29   2  14.837500
# 18283        25  16   2.771005
# 18287        64   3  26.246857
#
# [4337 rows x 3 columns]

# %%
df_rfm.apply(scale).plot.box()
# Out:
# <Axes: >

# %%
df_rfm.apply(scale).query('M>50')
# Out:
#                    R         F          M
# CustomerID
# 15098       0.899878 -0.165317  55.434876

# %%
df.query('CustomerID==15098')
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 222670    556442     22502      PICNIC BASKET WICKER SMALL        60
# 222680    556444     22502  PICNIC BASKET WICKER 60 PIECES        60
# 222682    556446     22502  PICNIC BASKET WICKER 60 PIECES         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  price_total
# 222670 2011-06-10 15:22:00       4.95       15098  United Kingdom        297.0
# 222680 2011-06-10 15:28:00     649.50       15098  United Kingdom      38970.0
# 222682 2011-06-10 15:33:00     649.50       15098  United Kingdom        649.5

# %%
df_rfm = df_rfm.drop(15098)

# %%
df_rfm.apply(scale).plot.box()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import PowerTransformer

# %%
scaler = PowerTransformer()

# %%
df_rfm_scaled = pd.DataFrame(scaler.fit_transform(df_rfm), index=df_rfm.index, columns=df_rfm.columns)
df_rfm_scaled
# Out:
#                    R         F         M
# CustomerID
# 12347      -1.563219  1.201866  0.407836
# 12348       0.323470  0.660670  1.329304
# 12349      -0.809134 -1.158070  0.426829
# 12350       1.568467 -1.158070  0.189376
# 12352      -0.307718  1.309671  0.653411
# ...              ...       ...       ...
# 18280       1.475652 -1.158070  0.085562
# 18281       1.107356 -1.158070 -0.491003
# 18282      -1.275046 -0.195707 -0.161007
# 18283      -1.500181  1.750302 -2.606380
# 18287      -0.181363  0.327225  0.524778
#
# [4336 rows x 3 columns]

# %%
df_rfm_scaled.plot.box()
# Out:
# <Axes: >

# %%
scaler.inverse_transform(df_rfm_scaled)
# Out:
# array([[24.        ,  7.        , 23.68131868],
#        [97.        ,  4.        , 57.97548387],
#        [40.        ,  1.        , 24.0760274 ],
#        ...,
#        [29.        ,  2.        , 14.8375    ],
#        [25.        , 16.        ,  2.77100529],
#        [64.        ,  3.        , 26.24685714]], shape=(4336, 3))

# %%
df_rfm.describe()
# Out:
#                  R            F            M
# count  4336.000000  4336.000000  4336.000000
# mean    114.032288     4.272601    34.554185
# std      99.968352     7.697927   129.202663
# min      22.000000     1.000000     1.450000
# 25%      39.000000     1.000000    12.339095
# 50%      72.000000     2.000000    17.715999
# 75%     163.250000     5.000000    24.843993
# max     395.000000   209.000000  4453.430000

# %%
df_rfm_clip = df_rfm.apply(lambda x: x.clip(upper=x.quantile(.95)))
df_rfm_clip.describe()
# Out:
#                  R            F            M
# count  4336.000000  4336.000000  4336.000000
# mean    112.248155     3.608164    23.634656
# std      95.504576     3.358999    20.993635
# min      22.000000     1.000000     1.450000
# 25%      39.000000     1.000000    12.339095
# 50%      72.000000     2.000000    17.715999
# 75%     163.250000     5.000000    24.843993
# max     333.000000    13.000000    91.768421

# %%
df_rfm_clip_scaled = df_rfm_clip.apply(scale)

# %% [markdown]
# # Step 4-5: Modeling & Model evaluation

# %% [markdown]
# ## K-Means

# %%
kelbow_visualizer(KMeans(), df_rfm_clip_scaled, k=10, timings=False)
# Out:
# KElbowVisualizer(ax=<Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>,
#                  estimator=KMeans(n_clusters=10), timings=False)

# %%
# Create list of dictionaries

cluster_metrics = silhouette_score, davies_bouldin_score, calinski_harabasz_score
cluster_metrics_results = []
X = df_rfm_clip_scaled.copy()

for k in range(2,11):
  model = KMeans(n_clusters=k, random_state=0)
  labels = model.fit_predict(X)
  cluster_results_dict = {'k': k}
  cluster_results_dict['inertia'] = model.inertia_
  for metric in cluster_metrics:
    cluster_results_dict[metric.__name__] = metric(X, labels)
  cluster_metrics_results.append(cluster_results_dict)

pd.DataFrame(cluster_metrics_results).set_index('k').style.background_gradient()
# Out:
# <style type="text/css">
# #T_c3b6d_row0_col0, #T_c3b6d_row0_col1, #T_c3b6d_row0_col2, #T_c3b6d_row2_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c3b6d_row0_col3, #T_c3b6d_row2_col2, #T_c3b6d_row8_col0, #T_c3b6d_row8_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c3b6d_row1_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_c3b6d_row1_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_c3b6d_row1_col2 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_c3b6d_row1_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_c3b6d_row2_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_c3b6d_row2_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_c3b6d_row3_col0 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_c3b6d_row3_col1 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_c3b6d_row3_col2 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_c3b6d_row3_col3 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_c3b6d_row4_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_c3b6d_row4_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_c3b6d_row4_col2 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_c3b6d_row4_col3 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_c3b6d_row5_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c3b6d_row5_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_c3b6d_row5_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_c3b6d_row5_col3 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_c3b6d_row6_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c3b6d_row6_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_c3b6d_row6_col2 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_c3b6d_row6_col3 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_c3b6d_row7_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c3b6d_row7_col1 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_c3b6d_row7_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_c3b6d_row7_col3 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_c3b6d_row8_col2 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_c3b6d_row8_col3 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c3b6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3b6d_level0_col0" class="col_heading level0 col0" >inertia</th>
#       <th id="T_c3b6d_level0_col1" class="col_heading level0 col1" >silhouette_score</th>
#       <th id="T_c3b6d_level0_col2" class="col_heading level0 col2" >davies_bouldin_score</th>
#       <th id="T_c3b6d_level0_col3" class="col_heading level0 col3" >calinski_harabasz_score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3b6d_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_c3b6d_row0_col0" class="data row0 col0" >9608.319042</td>
#       <td id="T_c3b6d_row0_col1" class="data row0 col1" >0.481575</td>
#       <td id="T_c3b6d_row0_col2" class="data row0 col2" >1.042550</td>
#       <td id="T_c3b6d_row0_col3" class="data row0 col3" >1533.485432</td>
#     </tr>
#     <tr>
#       <th id="T_c3b6d_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_c3b6d_row1_col0" class="data row1 col0" >6380.827963</td>
#       <td id="T_c3b6d_row1_col1" class="data row1 col1" >0.395222</td>
#       <td id="T_c3b6d_row1_col2" class="data row1 col2" >0.918987</td>
#       <td id="T_c3b6d_row1_col3" class="data row1 col3" >2250.147145</td>
#     </tr>
#     <tr>
#       <th id="T_c3b6d_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_c3b6d_row2_col0" class="data row2 col0" >3615.611638</td>
#       <td id="T_c3b6d_row2_col1" class="data row2 col1" >0.479553</td>
#       <td id="T_c3b6d_row2_col2" class="data row2 col2" >0.704462</td>
#       <td id="T_c3b6d_row2_col3" class="data row2 col3" >3751.144746</td>
#     </tr>
#     <tr>
#       <th id="T_c3b6d_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_c3b6d_row3_col0" class="data row3 col0" >3104.989759</td>
#       <td id="T_c3b6d_row3_col1" class="data row3 col1" >0.386168</td>
#       <td id="T_c3b6d_row3_col2" class="data row3 col2" >0.855067</td>
#       <td id="T_c3b6d_row3_col3" class="data row3 col3" >3453.313624</td>
#     </tr>
#     <tr>
#       <th id="T_c3b6d_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_c3b6d_row4_col0" class="data row4 col0" >2542.521220</td>
#       <td id="T_c3b6d_row4_col1" class="data row4 col1" >0.397775</td>
#       <td id="T_c3b6d_row4_col2" class="data row4 col2" >0.851237</td>
#       <td id="T_c3b6d_row4_col3" class="data row4 col3" >3564.616053</td>
#     </tr>
#     <tr>
#       <th id="T_c3b6d_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_c3b6d_row5_col0" class="data row5 col0" >2240.392476</td>
#       <td id="T_c3b6d_row5_col1" class="data row5 col1" >0.401925</td>
#       <td id="T_c3b6d_row5_col2" class="data row5 col2" >0.849436</td>
#       <td id="T_c3b6d_row5_col3" class="data row5 col3" >3467.623360</td>
#     </tr>
#     <tr>
#       <th id="T_c3b6d_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_c3b6d_row6_col0" class="data row6 col0" >1907.087195</td>
#       <td id="T_c3b6d_row6_col1" class="data row6 col1" >0.383633</td>
#       <td id="T_c3b6d_row6_col2" class="data row6 col2" >0.862005</td>
#       <td id="T_c3b6d_row6_col3" class="data row6 col3" >3598.989252</td>
#     </tr>
#     <tr>
#       <th id="T_c3b6d_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_c3b6d_row7_col0" class="data row7 col0" >1668.788329</td>
#       <td id="T_c3b6d_row7_col1" class="data row7 col1" >0.394132</td>
#       <td id="T_c3b6d_row7_col2" class="data row7 col2" >0.800834</td>
#       <td id="T_c3b6d_row7_col3" class="data row7 col3" >3675.183274</td>
#     </tr>
#     <tr>
#       <th id="T_c3b6d_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_c3b6d_row8_col0" class="data row8 col0" >1516.652722</td>
#       <td id="T_c3b6d_row8_col1" class="data row8 col1" >0.351693</td>
#       <td id="T_c3b6d_row8_col2" class="data row8 col2" >0.887890</td>
#       <td id="T_c3b6d_row8_col3" class="data row8 col3" >3641.928356</td>
#     </tr>
#   </tbody>
# </table>

# %%
kmeans = KMeans(4)
kmeans_labels = kmeans.fit_predict(df_rfm_clip_scaled)

# %%
px.scatter_3d(df_rfm_clip, x='R', y='F', z='M', color=kmeans_labels.astype(str), template='plotly_dark')

# %% [markdown]
# ## Hierarchical Clustering

# %%
kelbow_visualizer(AgglomerativeClustering(), df_rfm_clip_scaled, k=10, timings=False)
# Out:
# KElbowVisualizer(ax=<Axes: title={'center': 'Distortion Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='distortion score'>,
#                  estimator=AgglomerativeClustering(n_clusters=10),
#                  timings=False)

# %%
# Create list of dictionaries

cluster_metrics = silhouette_score, davies_bouldin_score, calinski_harabasz_score
cluster_metrics_results = []
X = df_rfm_clip_scaled.copy()

for k in range(2,11):
  model = AgglomerativeClustering(n_clusters=k)
  labels = model.fit_predict(X)
  cluster_results_dict = {'k': k}
  # cluster_results_dict['inertia'] = model.inertia_
  for metric in cluster_metrics:
    cluster_results_dict[metric.__name__] = metric(X, labels)
  cluster_metrics_results.append(cluster_results_dict)

pd.DataFrame(cluster_metrics_results).set_index('k').style.background_gradient()
# Out:
# <style type="text/css">
# #T_2373b_row0_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_2373b_row0_col1, #T_2373b_row2_col0, #T_2373b_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2373b_row0_col2, #T_2373b_row2_col1, #T_2373b_row7_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2373b_row1_col0 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_2373b_row1_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_2373b_row1_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_2373b_row2_col2 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_2373b_row3_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_2373b_row3_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_2373b_row4_col0 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_2373b_row4_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_2373b_row4_col2 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_2373b_row5_col0 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_2373b_row5_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_2373b_row5_col2 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_2373b_row6_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_2373b_row6_col1 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_2373b_row6_col2 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_2373b_row7_col1 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_2373b_row7_col2 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_2373b_row8_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_2373b_row8_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_2373b_row8_col2 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2373b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2373b_level0_col0" class="col_heading level0 col0" >silhouette_score</th>
#       <th id="T_2373b_level0_col1" class="col_heading level0 col1" >davies_bouldin_score</th>
#       <th id="T_2373b_level0_col2" class="col_heading level0 col2" >calinski_harabasz_score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2373b_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_2373b_row0_col0" class="data row0 col0" >0.361292</td>
#       <td id="T_2373b_row0_col1" class="data row0 col1" >1.331666</td>
#       <td id="T_2373b_row0_col2" class="data row0 col2" >1737.623791</td>
#     </tr>
#     <tr>
#       <th id="T_2373b_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_2373b_row1_col0" class="data row1 col0" >0.398928</td>
#       <td id="T_2373b_row1_col1" class="data row1 col1" >0.869855</td>
#       <td id="T_2373b_row1_col2" class="data row1 col2" >2104.783905</td>
#     </tr>
#     <tr>
#       <th id="T_2373b_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_2373b_row2_col0" class="data row2 col0" >0.431886</td>
#       <td id="T_2373b_row2_col1" class="data row2 col1" >0.761966</td>
#       <td id="T_2373b_row2_col2" class="data row2 col2" >2770.399918</td>
#     </tr>
#     <tr>
#       <th id="T_2373b_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_2373b_row3_col0" class="data row3 col0" >0.342136</td>
#       <td id="T_2373b_row3_col1" class="data row3 col1" >0.897329</td>
#       <td id="T_2373b_row3_col2" class="data row3 col2" >2872.239315</td>
#     </tr>
#     <tr>
#       <th id="T_2373b_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_2373b_row4_col0" class="data row4 col0" >0.348298</td>
#       <td id="T_2373b_row4_col1" class="data row4 col1" >0.791909</td>
#       <td id="T_2373b_row4_col2" class="data row4 col2" >2816.854970</td>
#     </tr>
#     <tr>
#       <th id="T_2373b_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_2373b_row5_col0" class="data row5 col0" >0.322680</td>
#       <td id="T_2373b_row5_col1" class="data row5 col1" >0.844326</td>
#       <td id="T_2373b_row5_col2" class="data row5 col2" >2848.491623</td>
#     </tr>
#     <tr>
#       <th id="T_2373b_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_2373b_row6_col0" class="data row6 col0" >0.287643</td>
#       <td id="T_2373b_row6_col1" class="data row6 col1" >0.967432</td>
#       <td id="T_2373b_row6_col2" class="data row6 col2" >2799.001327</td>
#     </tr>
#     <tr>
#       <th id="T_2373b_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_2373b_row7_col0" class="data row7 col0" >0.286883</td>
#       <td id="T_2373b_row7_col1" class="data row7 col1" >0.976982</td>
#       <td id="T_2373b_row7_col2" class="data row7 col2" >2832.797336</td>
#     </tr>
#     <tr>
#       <th id="T_2373b_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_2373b_row8_col0" class="data row8 col0" >0.298923</td>
#       <td id="T_2373b_row8_col1" class="data row8 col1" >0.953087</td>
#       <td id="T_2373b_row8_col2" class="data row8 col2" >2786.657350</td>
#     </tr>
#   </tbody>
# </table>

# %%
hclust = AgglomerativeClustering(n_clusters=4)
hclust_labels = hclust.fit_predict(df_rfm_clip_scaled)

# %%
px.scatter_3d(df_rfm_clip, x='R', y='F', z='M', color=hclust_labels.astype(str), template='plotly_dark')

# %% [markdown]
# ## Gaussian Mixture

# %%
# Select best model by covariance type and K (Practical Statistics for Data Scientists)
results = []
k_range = range(1,9)
covariance_types = ['full', 'tied', 'diag', 'spherical']
X = df_rfm_clip_scaled.copy()

for n_components in k_range:
  for covariance_type in covariance_types:
    mclust = GaussianMixture(n_components=n_components, n_init=10, warm_start=True, covariance_type=covariance_type)
    mclust.fit(X)
    results.append({
      'bic': mclust.bic(X),
      'n_components': n_components,
      'covariance_type': covariance_type,
    })

results = pd.DataFrame(results)
results.sort_values('bic').head()
# Out:
#             bic  n_components covariance_type
# 28   -47.650054             8            full
# 26   211.273842             7            diag
# 30  6718.084532             8            diag
# 24  6937.307558             7            full
# 22  8982.145593             6            diag

# %%
sns.lineplot(data=results, x='n_components', y='bic', hue='covariance_type');

# %%
mclust = GaussianMixture(n_components=5, covariance_type='full', n_init=10)
mclust_labels = mclust.fit_predict(df_rfm_clip_scaled)

# %%
px.scatter_3d(df_rfm_clip, x='R', y='F', z='M', color=mclust_labels.astype(str), template='plotly_dark')

# %% [markdown]
# # Step 5: Interpretação dos clusters

# %%
centers = pd.DataFrame(kmeans.cluster_centers_, columns=df_rfm_clip_scaled.columns)

# %%
# Adaptado do livro "Practical Statistics for Data Scientists"
fig,axes = plt.subplots(nrows=4, figsize=(14,12), sharex=True)

for i,ax in enumerate(axes):
  center = centers.loc[i,:]
  maxPC = 1.01 * center.abs().max()
  colors = ['green' if l > 0 else 'red' for l in center]
  center.plot.bar(ax=ax, color=colors)
  ax.set_ylabel(f'Cluster {i+1}')
  ax.set_ylim(-maxPC, maxPC)
  ax.axhline(color='gray')
  ax.xaxis.set_ticks_position('none') 

plt.xticks(rotation=60, ha='right')
plt.tight_layout()
plt.show()

# %%
(
  df_rfm_clip.assign(cluster=kmeans_labels)
  .groupby('cluster')
  .mean()
  .transpose()
  .style.background_gradient(cmap='YlOrRd', axis=1)
)
# Out:
# <style type="text/css">
# #T_7aad5_row0_col0 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_7aad5_row0_col1 {
#   background-color: #feb651;
#   color: #000000;
# }
# #T_7aad5_row0_col2, #T_7aad5_row1_col3, #T_7aad5_row2_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_7aad5_row0_col3, #T_7aad5_row1_col2, #T_7aad5_row2_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_7aad5_row1_col0 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_7aad5_row1_col1 {
#   background-color: #fed36f;
#   color: #000000;
# }
# #T_7aad5_row2_col2 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_7aad5_row2_col3 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# </style>
# <table id="T_7aad5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th id="T_7aad5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7aad5_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7aad5_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_7aad5_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aad5_level0_row0" class="row_heading level0 row0" >R</th>
#       <td id="T_7aad5_row0_col0" class="data row0 col0" >67.526002</td>
#       <td id="T_7aad5_row0_col1" class="data row0 col1" >121.317500</td>
#       <td id="T_7aad5_row0_col2" class="data row0 col2" >41.517018</td>
#       <td id="T_7aad5_row0_col3" class="data row0 col3" >261.201439</td>
#     </tr>
#     <tr>
#       <th id="T_7aad5_level0_row1" class="row_heading level0 row1" >F</th>
#       <td id="T_7aad5_row1_col0" class="data row1 col0" >2.703751</td>
#       <td id="T_7aad5_row1_col1" class="data row1 col1" >3.862500</td>
#       <td id="T_7aad5_row1_col2" class="data row1 col2" >10.191248</td>
#       <td id="T_7aad5_row1_col3" class="data row1 col3" >1.509764</td>
#     </tr>
#     <tr>
#       <th id="T_7aad5_level0_row2" class="row_heading level0 row2" >M</th>
#       <td id="T_7aad5_row2_col0" class="data row2 col0" >17.106104</td>
#       <td id="T_7aad5_row2_col1" class="data row2 col1" >80.496497</td>
#       <td id="T_7aad5_row2_col2" class="data row2 col2" >20.426973</td>
#       <td id="T_7aad5_row2_col3" class="data row2 col3" >18.033822</td>
#     </tr>
#   </tbody>
# </table>
